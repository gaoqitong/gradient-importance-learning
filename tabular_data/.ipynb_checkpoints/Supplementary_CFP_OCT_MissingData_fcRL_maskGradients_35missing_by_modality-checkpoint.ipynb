# %%
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.examples.tutorials.mnist import input_data
import os 
import multiprocessing as mp
from sklearn.metrics import roc_auc_score, average_precision_score
import multiprocessing as mp
from qnetwork import *
from utils import *
slim = tf.contrib.slim
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
SEED = 2599
np.random.seed(SEED)
tf.set_random_seed(SEED)
import random
random.seed(SEED)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0426 21:00:26.640228 140458971993920 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0426 21:00:26.640682 140458971993920 module_wrapper.py:139] From qnetwork.py:50: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.

# %%
normal_train = np.loadtxt("./data/normal_train_all_35_missing_by_modality.txt")
abnormal_train = np.loadtxt("./data/abnormal_train_all_35_missing_by_modality.txt")

normal_test = np.loadtxt("./data/normal_test_all_35_missing_by_modality.txt")
abnormal_test = np.loadtxt("./data/abnormal_test_all_35_missing_by_modality.txt")

# %%
data_train = np.vstack([normal_train, abnormal_train]).astype(np.float32)
data_label_train = np.concatenate([np.zeros(len(normal_train)), np.ones(len(abnormal_train))]).astype(np.int32)
data_mask_train = np.isnan(data_train).astype(np.float32)

data_test = np.vstack([normal_test, abnormal_test]).astype(np.float32)
data_label_test = np.concatenate([np.zeros(len(normal_test)), np.ones(len(abnormal_test))]).astype(np.int32)
data_mask_test = np.isnan(data_test).astype(np.float32)

# %%
nan_replacement = 0.

# %%
data_train[np.isnan(data_train)] = nan_replacement
data_test[np.isnan(data_test)] = nan_replacement

# %%
import matplotlib.pyplot as plt
import scipy.stats as stats

lower, upper = 0, 1
mu, sigma = 0, 0.2
left_truncnorm = stats.truncnorm(
    (lower - mu) / sigma, (upper - mu) / sigma, loc=mu, scale=sigma)
right_truncnorm = stats.truncnorm(
    (lower - 1.) / sigma, (upper - 1.) / sigma, loc=1., scale=sigma)

fig, ax = plt.subplots(1, sharex=True)
ax.hist(np.concatenate([left_truncnorm.rvs(10000),right_truncnorm.rvs(10000)]), normed=True)
# Out:
# /home/gaoqitong/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# (array([1.96707608, 1.50105805, 0.89303454, 0.44501721, 0.19950772,
#         0.21050814, 0.43001663, 0.91603543, 1.54655981, 1.89157316]),
#  array([2.06842961e-05, 1.00016817e-01, 2.00012949e-01, 3.00009082e-01,
#         4.00005214e-01, 5.00001347e-01, 5.99997479e-01, 6.99993612e-01,
#         7.99989744e-01, 8.99985877e-01, 9.99982009e-01]),
#  <a list of 10 Patch objects>)

# %%
def train(args):
    start_learning_rate, decay_step, decay_rate, rl_actor, rl_critic = args


    # Training Parameters
#     start_learning_rate = 0.005
#     decay_step = 500
#     decay_rate = .9

    weights = [1000, 1000]

    rl_reward_thres_for_decay = -25

    session_config = tf.ConfigProto(log_device_placement=False)
    session_config.gpu_options.allow_growth = True

    training_steps = 3000
    batch_size = 128

    # Network Parameters
    num_input = 4101 # MNIST data input (img shape: 28*28)
    timesteps = 1 # timesteps
#     num_hidden = 128 # hidden layer num of features
    num_classes = 2 # MNIST total classes (0-9 digits)

    display_step = 10

    gpu = 0

    graph = tf.Graph()

    file_appendix = "CFP_OCT_MissingData_35_missing_by_modality_FCRL_maskGradients_" + str(start_learning_rate) + "_" + str(decay_step) + "_" + str(decay_rate) + "_" + str(weights[0]) + "_" + str(weights[1]) + "_" + str(rl_actor) + "_" + str(rl_critic)

    def build_net(x, is_training=True, reuse=tf.AUTO_REUSE, graph=graph):

        with graph.as_default():

            with tf.variable_scope("NN", reuse=tf.AUTO_REUSE) as scope:
                with slim.arg_scope([slim.fully_connected], 
                                        activation_fn=tf.nn.relu,
                                        weights_initializer=tf.random_uniform_initializer(0.001, 0.01),
                                        weights_regularizer=slim.l2_regularizer(0.02),
                                        biases_regularizer=slim.l2_regularizer(0.02),
                                        normalizer_fn = slim.batch_norm,
                                        normalizer_params = {"is_training": is_training},
                                        reuse = reuse,
                                        scope = scope):

                    fc1 = slim.fully_connected(x, weights[0], scope='fc1')
                    fc2 = slim.fully_connected(fc1, weights[1], scope='fc2')
                    logits = slim.fully_connected(fc2,num_classes,activation_fn=None, weights_regularizer=None, normalizer_fn=None, scope='logits')
                    pred = slim.softmax(logits, scope='pred')

                    return logits, pred, fc1


    def gen_train():
        for i in range(data_train.shape[0]):
            label = np.zeros(2)
            label[data_label_train[i]] = 1.
            yield data_train[i], label, data_mask_train[i]

    def gen_test():
        for i in range(data_test.shape[0]):
            label = np.zeros(2)
            label[data_label_test[i]] = 1.
            yield data_test[i], label, data_mask_test[i]


    with graph.as_default():

        dataset_train = tf.data.Dataset.from_generator(gen_train, (tf.float32, tf.float32, tf.int32), ([4101],[2],[4101])).repeat(30000).shuffle(5000).batch(batch_size)
        input_train, label_train, mask_train = dataset_train.make_one_shot_iterator().get_next()

        dataset_test = tf.data.Dataset.from_generator(gen_test, (tf.float32, tf.float32, tf.int32), ([4101],[ 2],[4101])).repeat(30000).batch(data_test.shape[0])
        input_test, label_test, mask_test = dataset_test.make_one_shot_iterator().get_next()

        input_train_holder = tf.placeholder(shape=[batch_size, num_input*timesteps], dtype=tf.float32)
        label_train_holder = tf.placeholder(shape=[batch_size, num_classes], dtype=tf.float32)
        mask_train_holder = tf.placeholder(shape=[batch_size, num_input*timesteps], dtype=tf.int32)
        logits, prediction, feature = build_net(input_train_holder)

        all_test = data_test

        logits_final, pred_final, _ = build_net(input_test, is_training=False)

        fc_variables = [v for v in tf.trainable_variables() if v.name.find("NN")!=-1]

        # Define loss and optimizer
        loss_op = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=label_train_holder) + tf.reduce_mean(tf.get_collection(tf.GraphKeys.REGULARIZATION_LOSSES, scope="NN"))
        loss_mean = tf.reduce_mean(loss_op, axis=0)
        learning_rate = tf.train.exponential_decay(start_learning_rate, tf.train.get_or_create_global_step(), decay_steps=decay_step, decay_rate=decay_rate)
        optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)

        update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)

        grads = tf.vectorized_map(lambda x: optimizer.compute_gradients(x, fc_variables), loss_op)
        grads = [g[0] for g in grads]

        grad_attention = tf.placeholder(shape=[batch_size, num_input*timesteps], dtype=tf.float32)
    #     not_mask_train = 1-tf.cast(mask_train, tf.float32)
        grads[0] = grads[0]*grad_attention[...,tf.newaxis]

        grads = [tf.reduce_mean(g,axis=0) for g in grads]
        
        with tf.control_dependencies(update_ops):
            grads_update_op = optimizer.apply_gradients(zip(grads, fc_variables))

        train_correct_pred = tf.equal(tf.cast(tf.argmax(prediction, 1),tf.float32), tf.cast(tf.argmax(label_train_holder, 1),tf.float32) )
        train_accuracy = tf.reduce_mean(tf.cast(train_correct_pred, tf.float32))
        train_kld = tf.keras.losses.KLDivergence()(prediction, label_train_holder)

        final_correct_pred = tf.equal(tf.argmax(pred_final, 1), tf.argmax(label_test, 1))
        final_accuracy = tf.reduce_mean(tf.cast(final_correct_pred, tf.float32))
        final_kld = tf.keras.losses.KLDivergence()(pred_final, label_test)

        max_final_acc = tf.Variable(0, dtype=tf.float32, name="max_final_acc", trainable=False)
        assign_max_final_acc = max_final_acc.assign(final_accuracy)
        
        final_score = pred_final[:,1]

    #     final_score = logits_final[:,1]

        # Initialize the variables (i.e. assign their default values



    with graph.as_default():
        actor = Actor(graph=graph, state_dim=num_input*timesteps*2+weights[0]+num_classes, action_dim=num_input*timesteps, learning_rate=rl_actor, tau=0.001, batch_size=batch_size, save_path="./saved_model/"+file_appendix+"/actor.ckpt")
        critic = Critic(graph=graph, state_dim=num_input*timesteps*2+weights[0]+num_classes, action_dim=num_input*timesteps, learning_rate=rl_critic, tau=0.001, gamma=0.99, save_path="./saved_model/"+file_appendix+"/critic.ckpt")
        init = tf.global_variables_initializer()
        saver = tf.train.Saver()


    # Start training
    with tf.Session(config=session_config, graph=graph) as sess:
        sess.run(init)
        EXPLORATION_RATE = 0.4
        GUIDE_RATE = .5
        ep_reward = 0
        ep_ave_max_q = 0

        data_in, label_in, s_mask = sess.run([input_train, label_train, mask_train])
        s_1, s_2 = sess.run([logits, feature], feed_dict = {input_train_holder:data_in, label_train_holder:label_in, mask_train_holder:s_mask})
        s = np.hstack([data_in,s_mask,s_1,s_2])

        reward_list = []
        ave_max_q_list = []
        replay_buffer = ReplayBuffer(10**4, random_seed=SEED)

        # Run the initializer


        max_auc = 0.
        max_ap = 0.
        max_acc = 0.
        min_kld = 1000.

        actor.update_target_network(sess)
        critic.update_target_network(sess)

        for step in range(training_steps):
            rand_num = np.random.rand(1)

            if rand_num <= EXPLORATION_RATE:
                a = np.concatenate([left_truncnorm.rvs(num_input*(timesteps//2)*batch_size),right_truncnorm.rvs(num_input*(timesteps//2+1)*batch_size)])
                np.random.shuffle(a)
                a = a.reshape(batch_size,-1).astype(np.float32)

            elif rand_num <= GUIDE_RATE+EXPLORATION_RATE and rand_num > EXPLORATION_RATE:
                a = (1-s_mask).astype(np.float32)

            else:
                a = actor.predict(s, sess)
    #             print "a: ", a
    #             print "mask: ", s_mask

            _, kld, test_kld = sess.run([grads_update_op, train_kld, final_kld], feed_dict={grad_attention:a, input_train_holder:data_in, label_train_holder:label_in, mask_train_holder:s_mask})
            acc = sess.run([final_accuracy])
            data_in, label_in, s2_mask = sess.run([input_train, label_train, mask_train])
            s2_1, s2_2 = sess.run([logits, feature], feed_dict = {input_train_holder:data_in, label_train_holder:label_in})
            s2 = np.hstack([data_in,s2_mask,s2_1,s2_2])

    #         r = np.repeat(acc + auc + ap - 3., batch_size)
            r = np.repeat(-kld, batch_size)
            replay_buffer.add_batch([list(i) for i in zip(s,a,r,s2)])

            if replay_buffer.size() > batch_size:
                s_batch, a_batch, r_batch, s2_batch = replay_buffer.sample_batch(batch_size)

                # Calculate targets
                target_q = critic.predict_target(
                    s2_batch, actor.predict_target(s2_batch, sess), sess)

                y_i = []
                for k in range(batch_size):
                    y_i.append(r_batch[k] + critic.gamma * target_q[k])

                # Update the critic given the targets
                predicted_q_value, _ = critic.train(
                    s_batch, a_batch, np.reshape(y_i, (batch_size, 1)), step, sess)

                ave_max_q = np.amax(predicted_q_value)
                ave_max_q_list += [ave_max_q]

                # Update the actor policy using the sampled gradient
                a_outs = actor.predict(s_batch, sess)
                grads = critic.action_gradients(s_batch, a_outs, sess)
                actor.train(s_batch, grads[0], step, sess)

                # Update target networks
                actor.update_target_network(sess)
                critic.update_target_network(sess)

            s = s2
            s_mask = s2_mask

            reward_list += [r[0]]
            
            if EXPLORATION_RATE > 0.2:
                EXPLORATION_RATE = EXPLORATION_RATE * 0.999
            if GUIDE_RATE > 0.3:
                GUIDE_RATE = GUIDE_RATE * 0.999


            if step % display_step == 0 and step > 0:
                # Calculate batch loss and accuracy
                loss, acc, train_acc = sess.run([loss_mean, final_accuracy, train_accuracy], feed_dict = {input_train_holder:data_in, label_train_holder:label_in})
                auc = roc_auc_score(data_label_test, final_score.eval())
                ap = average_precision_score(data_label_test, final_score.eval())
                if np.mean(reward_list[-display_step:]) >= rl_reward_thres_for_decay:
                    actor.decay_learning_rate(0.965, sess)
                    critic.decay_learning_rate(0.965, sess)

                if acc > max_acc:
                    max_acc = acc
                    max_auc = auc
                    max_ap = ap
                    min_kld = test_kld
                    sess.run(assign_max_final_acc)
                    saver.save(sess, "./saved_model/"+file_appendix+"/best.ckpt")
                print "Step " + str(step) + ", Minibatch Loss= " + \
                      "{:.4f}".format(loss) + ", Training Accuracy= " + \
                      "{:.3f}".format(train_acc) + ", Testing Acc= " + "{:3f}".format(acc) + \
                      ", Max Final Accuracy= ", "{:6f}".format(max_final_acc.eval()) + \
                      ", Max AUC= ", "{:6f}".format(max_auc) + \
                      ", Max AP= ", "{:6f}".format(max_ap)
                with open("./stats/rl_log/" + file_appendix + ".txt", "ab") as myfile:
                    myfile.write("Step " + str(step) + ", Reward=" + str(np.sum(reward_list[-display_step:])) + ", Minibatch Loss= " + "{:.4f}".format(loss) + ", Training Accuracy= " + "{:.3f}".format(train_acc) + ", Testing Acc= " + "{:3f}".format(final_accuracy.eval()) + ", Max Final Accuracy= " + "{:6f}".format(max_final_acc.eval()) + ", Exploration= " + "{:6f}".format(EXPLORATION_RATE) + ", Guide= " + "{:6f}".format(GUIDE_RATE) + "\n")
        print "Optimization Finished!"

        print "Testing Accuracy:", sess.run(max_final_acc)
        with open("./stats/CFP_OCT_MissingData_35_missing_by_modality_FCRL_maskGradients.txt", "ab") as myfile:
            myfile.write("%.9f\t%i\t%.3f\t%i\t%i\t%.9f\t%.9f\t%.6f\t%.6f\t%.6f\n" %(start_learning_rate, decay_step, decay_rate, weights[0], weights[1], rl_actor, rl_critic, max_final_acc.eval(), max_auc, max_ap))

# %%
LRs = [ 0.000501, 0.001, 0.0001, 0.00005, 0.00001]
DSs = [750, 1500]
DRs = [0.9, 0.8]
ACs = [0.00005, 0.0001]
CRs = [0.0005, 0.001]

pool = mp.Pool(2)
pool.map(train, [(lr, ds, dr, rl_a, rl_c) for lr in LRs for ds in DSs for dr in DRs for rl_a in ACs for rl_c in CRs])
pool.close()
pool.join()
# Out:
# W0426 21:01:13.295917 140458971993920 deprecation.py:323] From <ipython-input-7-d2ba888ab4c2>:73: make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# W0426 21:01:13.296875 140458971993920 deprecation.py:323] From <ipython-input-7-d2ba888ab4c2>:73: make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# W0426 21:01:13.358346 140458971993920 deprecation.py:323] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1866: apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0426 21:01:13.360702 140458971993920 deprecation.py:323] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1866: apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0426 21:01:13.492568 140458971993920 deprecation.py:323] From <ipython-input-7-d2ba888ab4c2>:90: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0426 21:01:13.498220 140458971993920 deprecation.py:323] From <ipython-input-7-d2ba888ab4c2>:90: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0426 21:01:14.960064 140458971993920 deprecation.py:323] From qnetwork.py:37: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W0426 21:01:15.028157 140458971993920 deprecation.py:323] From qnetwork.py:37: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W0426 21:01:15.052350 140458971993920 module_wrapper.py:139] From qnetwork.py:47: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0426 21:01:15.114773 140458971993920 module_wrapper.py:139] From qnetwork.py:47: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0426 21:01:15.455071 140458971993920 module_wrapper.py:139] From qnetwork.py:137: The name tf.losses.mean_squared_error is deprecated. Please use tf.compat.v1.losses.mean_squared_error instead.
#
# W0426 21:01:15.467643 140458971993920 deprecation.py:323] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0426 21:01:15.535115 140458971993920 module_wrapper.py:139] From qnetwork.py:137: The name tf.losses.mean_squared_error is deprecated. Please use tf.compat.v1.losses.mean_squared_error instead.
#
# W0426 21:01:15.548410 140458971993920 deprecation.py:323] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Step 10, Minibatch Loss= 0.7703, Training Accuracy= 0.672, Testing Acc= 0.745614, Max Final Accuracy=  0.745614, Max AUC=  0.762235, Max AP=  0.814719
# Step 10, Minibatch Loss= 0.7703, Training Accuracy= 0.672, Testing Acc= 0.745614, Max Final Accuracy=  0.745614, Max AUC=  0.762235, Max AP=  0.814719
# Step 20, Minibatch Loss= 0.6995, Training Accuracy= 0.703, Testing Acc= 0.500000, Max Final Accuracy=  0.745614, Max AUC=  0.762235, Max AP=  0.814719
# Step 20, Minibatch Loss= 0.6994, Training Accuracy= 0.703, Testing Acc= 0.500000, Max Final Accuracy=  0.745614, Max AUC=  0.762235, Max AP=  0.814719
# Step 30, Minibatch Loss= 0.6510, Training Accuracy= 0.648, Testing Acc= 0.701754, Max Final Accuracy=  0.745614, Max AUC=  0.762235, Max AP=  0.814719
# Step 30, Minibatch Loss= 0.6483, Training Accuracy= 0.648, Testing Acc= 0.701754, Max Final Accuracy=  0.745614, Max AUC=  0.762235, Max AP=  0.814719
# Step 40, Minibatch Loss= 0.4985, Training Accuracy= 0.844, Testing Acc= 0.666667, Max Final Accuracy=  0.745614, Max AUC=  0.762235, Max AP=  0.814719
# Step 40, Minibatch Loss= 0.4952, Training Accuracy= 0.844, Testing Acc= 0.657895, Max Final Accuracy=  0.745614, Max AUC=  0.762235, Max AP=  0.814719
# Step 50, Minibatch Loss= 0.5718, Training Accuracy= 0.703, Testing Acc= 0.500000, Max Final Accuracy=  0.745614, Max AUC=  0.762235, Max AP=  0.814719
# Step 50, Minibatch Loss= 0.5812, Training Accuracy= 0.734, Testing Acc= 0.614035, Max Final Accuracy=  0.745614, Max AUC=  0.762235, Max AP=  0.814719
# Step
Testing Acc= 0.500000, Max Final Accuracy=  0.771930, Max AUC=  0.854263, Max AP=  0.861752
# Step 1360, Minibatch Loss= 0.3366, Training Accuracy= 0.938, Testing Acc= 0.561404, Max Final Accuracy=  0.815789, Max AUC=  0.877962, Max AP=  0.898888
# Step 1390, Minibatch Loss= 0.3260, Training Accuracy= 0.930, Testing Acc= 0.614035, Max Final Accuracy=  0.771930, Max AUC=  0.854263, Max AP=  0.861752
# Step 1370, Minibatch Loss= 0.4417, Training Accuracy= 0.906, Testing Acc= 0.561404, Max Final Accuracy=  0.815789, Max AUC=  0.877962, Max AP=  0.898888
# Step 1400, Minibatch Loss= 0.3205, Training Accuracy= 0.953, Testing Acc= 0.596491, Max Final Accuracy=  0.771930, Max AUC=  0.854263, Max AP=  0.861752
# Step 1380, Minibatch Loss= 0.4836, Training Accuracy= 0.859, Testing Acc= 0.578947, Max Final Accuracy=  0.815789, Max AUC=  0.877962, Max AP=  0.898888
# Step 1410, Minibatch Loss= 0.3707, Training Accuracy= 0.914, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.854263, Max AP=  0.861752
# Step 1390, Minibatch Loss= 0.3113, Training Accuracy= 0.961, Testing Acc= 0.570175, Max Final Accuracy=  0.815789, Max AUC=  0.877962, Max AP=  0.898888
# Step 1420, Minibatch Loss= 0.3647, Training Accuracy= 0.906, Testing Acc= 0.500000, Max Final Accuracy=  0.771930, Max AUC=  0.854263, Max AP=  0.861752
# Step 1400, Minibatch Loss= 0.3828, Training Accuracy= 0.891, Testing Acc= 0.578947, Max Final Accuracy=  0.815789, Max AUC=  0.877962, Max AP=  0.898888
# Step 1430, Minibatch Loss= 0.5369, Training Accuracy= 0.828, Testing Acc= 0.605263, Max Final Accuracy=  0.771930, Max AUC=  0.854263, Max AP=  0.861752
# Step 1410, Minibatch Loss= 0.3445, Training Accuracy= 0.922, Testing Acc= 0.500000, Max Final Accuracy=  0.815789, Max AUC=  0.877962, Max AP=  0.898888
# Step 1440, Minibatch Loss= 0.3458, Training Accuracy= 0.906, Testing Acc= 0.570175, Max Final Accuracy=  0.771930, Max AUC=  0.854263, Max AP=  0.861752
# Step 1420, Minibatch Loss= 0.4213, Training Accuracy= 0.875, Testing Acc= 0.500000, Max Final Accuracy=  0.815789, Max AUC=  0.877962, Max AP=  0.898888
# ...
# Step 2590, Minibatch Loss= 0.2093, Training Accuracy= 0.930, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2010, Minibatch Loss= 0.2745, Training Accuracy= 0.852, Testing Acc= 0.508772, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2600, Minibatch Loss= 0.1945, Training Accuracy= 0.906, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2020, Minibatch Loss= 0.2416, Training Accuracy= 0.906, Testing Acc= 0.508772, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2610, Minibatch Loss= 0.2078, Training Accuracy= 0.891, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2030, Minibatch Loss= 0.1840, Training Accuracy= 0.938, Testing Acc= 0.508772, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2620, Minibatch Loss= 0.2731, Training Accuracy= 0.875, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2040, Minibatch Loss= 0.2257, Training Accuracy= 0.906, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2630, Minibatch Loss= 0.2832, Training Accuracy= 0.859, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2050, Minibatch Loss= 0.2261, Training Accuracy= 0.945, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2640, Minibatch Loss= 0.2046, Training Accuracy= 0.914, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2060, Minibatch Loss= 0.2447, Training Accuracy= 0.906, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2650, Minibatch Loss= 0.2150, Training Accuracy= 0.875, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2070, Minibatch Loss= 0.2827, Training Accuracy= 0.875, Testing Acc= 0.508772, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2080, Minibatch Loss= 0.3030, Training Accuracy= 0.867, Testing Acc= 0.508772, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2660, Minibatch Loss= 0.2207, Training Accuracy= 0.938, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2090, Minibatch Loss= 0.2385, Training Accuracy= 0.867, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2670, Minibatch Loss= 0.2547, Training Accuracy= 0.883, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2100, Minibatch Loss= 0.2703, Training Accuracy= 0.898, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2680, Minibatch Loss= 0.2578, Training Accuracy= 0.891, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2110, Minibatch Loss= 0.2655, Training Accuracy= 0.898, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2690, Minibatch Loss= 0.2173, Training Accuracy= 0.914, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2120, Minibatch Loss= 0.2229, Training Accuracy= 0.906, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2700, Minibatch Loss= 0.2160, Training Accuracy= 0.898, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2130, Minibatch Loss= 0.2678, Training Accuracy= 0.875, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2710, Minibatch Loss= 0.1808, Training Accuracy= 0.930, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2140, Minibatch Loss= 0.2190, Training Accuracy= 0.914, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2720, Minibatch Loss= 0.1755, Training Accuracy= 0.945, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2150, Minibatch Loss= 0.3175, Training Accuracy= 0.852, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2730, Minibatch Loss= 0.1823, Training Accuracy= 0.930, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2160, Minibatch Loss= 0.2735, Training Accuracy= 0.891, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2740, Minibatch Loss= 0.2052, Training Accuracy= 0.914, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2170, Minibatch Loss= 0.2040, Training Accuracy= 0.953, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2750, Minibatch Loss= 0.2420, Training Accuracy= 0.891, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2180, Minibatch Loss= 0.2499, Training Accuracy= 0.906, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2760, Minibatch Loss= 0.1827, Training Accuracy= 0.930, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2190, Minibatch Loss= 0.2983, Training Accuracy= 0.852, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2770, Minibatch Loss= 0.2381, Training Accuracy= 0.898, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2200, Minibatch Loss= 0.2761, Training Accuracy= 0.867, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2780, Minibatch Loss= 0.1836, Training Accuracy= 0.938, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2210, Minibatch Loss= 0.2173, Training Accuracy= 0.945, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2790, Minibatch Loss= 0.1901, Training Accuracy= 0.914, Testing Acc= 0.552632, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2220, Minibatch Loss= 0.3930, Training Accuracy= 0.875, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2800, Minibatch Loss= 0.2666, Training Accuracy= 0.859, Testing Acc= 0.552632, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2230, Minibatch Loss= 0.2712, Training Accuracy= 0.914, Testing Acc= 0.508772, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2810, Minibatch Loss= 0.2152, Training Accuracy= 0.898, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2240, Minibatch Loss= 0.2260, Training Accuracy= 0.914, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2820, Minibatch Loss= 0.2369, Training Accuracy= 0.867, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2250, Minibatch Loss= 0.1831, Training Accuracy= 0.969, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2830, Minibatch Loss= 0.2024, Training Accuracy= 0.898, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2260, Minibatch Loss= 0.2592, Training Accuracy= 0.914, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2840, Minibatch Loss= 0.1703, Training Accuracy= 0.938, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2270, Minibatch Loss= 0.2590, Training Accuracy= 0.898, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2850, Minibatch Loss= 0.2167, Training Accuracy= 0.906, Testing Acc= 0.543860, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2280, Minibatch Loss= 0.4020, Training Accuracy= 0.828, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2860, Minibatch Loss= 0.2034, Training Accuracy= 0.914, Testing Acc= 0.552632, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2290, Minibatch Loss= 0.2104, Training Accuracy= 0.945, Testing Acc= 0.526316, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2870, Minibatch Loss= 0.2184, Training Accuracy= 0.891, Testing Acc= 0.552632, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2300, Minibatch Loss= 0.2537, Training Accuracy= 0.867, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2880, Minibatch Loss= 0.3710, Training Accuracy= 0.836, Testing Acc= 0.552632, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2310, Minibatch Loss= 0.2470, Training Accuracy= 0.883, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2320, Minibatch Loss= 0.2154, Training Accuracy= 0.930, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2890, Minibatch Loss= 0.2000, Training Accuracy= 0.922, Testing Acc= 0.552632, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2330, Minibatch Loss= 0.2410, Training Accuracy= 0.898, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2900, Minibatch Loss= 0.1903, Training Accuracy= 0.906, Testing Acc= 0.552632, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2340, Minibatch Loss= 0.1785, Training Accuracy= 0.922, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2910, Minibatch Loss= 0.1755, Training Accuracy= 0.914, Testing Acc= 0.552632, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2350, Minibatch Loss= 0.2168, Training Accuracy= 0.922, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2920, Minibatch Loss= 0.1887, Training Accuracy= 0.922, Testing Acc= 0.552632, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2360, Minibatch Loss= 0.2164, Training Accuracy= 0.938, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2930, Minibatch Loss= 0.1844, Training Accuracy= 0.938, Testing Acc= 0.552632, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2370, Minibatch Loss= 0.2665, Training Accuracy= 0.891, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2940, Minibatch Loss= 0.2306, Training Accuracy= 0.875, Testing Acc= 0.552632, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2380, Minibatch Loss= 0.2441, Training Accuracy= 0.859, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2950, Minibatch Loss= 0.1716, Training Accuracy= 0.953, Testing Acc= 0.552632, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2390, Minibatch Loss= 0.2352, Training Accuracy= 0.906, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2960, Minibatch Loss= 0.2144, Training Accuracy= 0.914, Testing Acc= 0.552632, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2400, Minibatch Loss= 0.2731, Training Accuracy= 0.867, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2970, Minibatch Loss= 0.2317, Training Accuracy= 0.891, Testing Acc= 0.552632, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2410, Minibatch Loss= 0.1826, Training Accuracy= 0.938, Testing Acc= 0.526316, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2980, Minibatch Loss= 0.2059, Training Accuracy= 0.906, Testing Acc= 0.552632, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2420, Minibatch Loss= 0.2372, Training Accuracy= 0.875, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2990, Minibatch Loss= 0.2275, Training Accuracy= 0.898, Testing Acc= 0.552632, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2430, Minibatch Loss= 0.2745, Training Accuracy= 0.844, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Optimization Finished!
# Testing Accuracy: 0.7719298
# Step 2440, Minibatch Loss= 0.1743, Training Accuracy= 0.953, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2450, Minibatch Loss= 0.1676, Training Accuracy= 0.930, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 10, Minibatch Loss= 1.3086, Training Accuracy= 0.672, Testing Acc= 0.508772, Max Final Accuracy=  0.508772, Max AUC=  0.744845, Max AP=  0.828098
# Step 2460, Minibatch Loss= 0.1791, Training Accuracy= 0.938, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 20, Minibatch Loss= 1.2975, Training Accuracy= 0.672, Testing Acc= 0.587719, Max Final Accuracy=  0.587719, Max AUC=  0.753924, Max AP=  0.824648
# Step 2470, Minibatch Loss= 0.2640, Training Accuracy= 0.875, Testing Acc= 0.526316, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 30, Minibatch Loss= 1.2547, Training Accuracy= 0.672, Testing Acc= 0.587719, Max Final Accuracy=  0.587719, Max AUC=  0.753924, Max AP=  0.824648
# Step 2480, Minibatch Loss= 0.1851, Training Accuracy= 0.922, Testing Acc= 0.526316, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 40, Minibatch Loss= 1.2359, Training Accuracy= 0.562, Testing Acc= 0.640351, Max Final Accuracy=  0.640351, Max AUC=  0.763158, Max AP=  0.821541
# Step 2490, Minibatch Loss= 0.2279, Training Accuracy= 0.906, Testing Acc= 0.517544, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 2500, Minibatch Loss= 0.2225, Training Accuracy= 0.914, Testing Acc= 0.526316, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 50, Minibatch Loss= 1.2494, Training Accuracy= 0.641, Testing Acc= 0.649123, Max Final Accuracy=  0.649123, Max AUC=  0.763004, Max AP=  0.819316
# Step 2510, Minibatch Loss= 0.2578, Training Accuracy= 0.898, Testing Acc= 0.526316, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 60, Minibatch Loss= 1.2178, Training Accuracy= 0.695, Testing Acc= 0.666667, Max Final Accuracy=  0.666667, Max AUC=  0.767929, Max AP=  0.819316
# Step 2520, Minibatch Loss= 0.1963, Training Accuracy= 0.938, Testing Acc= 0.526316, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 70, Minibatch Loss= 1.1799, Training Accuracy= 0.539, Testing Acc= 0.666667, Max Final Accuracy=  0.666667, Max AUC=  0.767929, Max AP=  0.819316
# Step 2530, Minibatch Loss= 0.2300, Training Accuracy= 0.906, Testing Acc= 0.526316, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 80, Minibatch Loss= 1.1659, Training Accuracy= 0.586, Testing Acc= 0.684211, Max Final Accuracy=  0.684211, Max AUC=  0.770391, Max AP=  0.816670
# Step 2540, Minibatch Loss= 0.2430, Training Accuracy= 0.883, Testing Acc= 0.526316, Max Final Accuracy=  0.771930, Max AUC=  0.776547, Max AP=  0.780170
# Step 90, Minibatch Loss= 1.2032, Training Accuracy= 0.547, Testing Acc= 0.684211, Max Final Accuracy=  0.684211, Max AUC=  0.770391, Max AP=  0.816670
