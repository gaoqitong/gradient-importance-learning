# %%
# from tensorflow.python.ops.rnn import rnn_cell_impl, _should_cache, nest, vs, tensor_shape, _is_keras_rnn_cell

# %%
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.examples.tutorials.mnist import input_data
import os 
import multiprocessing as mp
from qnetwork import *
from utils import *
import pandas as pd
from sklearn.metrics import roc_auc_score, average_precision_score
rnn = tf.contrib.rnn
slim = tf.contrib.slim
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import random
SEED = 2599
np.random.seed(SEED)
tf.set_random_seed(SEED)
random.seed(SEED)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0530 20:11:40.388796 140431006984000 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0530 20:11:40.389256 140431006984000 module_wrapper.py:139] From qnetwork.py:50: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.

# %%
# truncate all sequences to 8 timesteps; pad the ones that are shorter than 8
def trun_pad(in_pd_frame):
    if len(in_pd_frame) >= 8:
        return in_pd_frame[:8]
    else:
#         return pd.concat([in_pd_frame, pd.concat([in_pd_frame.iloc[-1] for _ in range(8-len(in_pd_frame))])])
        return pd.concat([in_pd_frame, pd.concat([in_pd_frame.iloc[-1,:] for _ in range(8-len(in_pd_frame))], axis=1).T])

# %%
df_shock_train = pd.read_csv("./data/df_shock_train_fix_l.csv", index_col="TrainSampleIdx")
df_shock_test = pd.read_csv("./data/df_shock_test_fix_l.csv", index_col="TrainSampleIdx")
df_non_shock_train = pd.read_csv("./data/df_non_shock_train_fix_l.csv", index_col="TrainSampleIdx")
df_non_shock_test = pd.read_csv("./data/df_non_shock_test_fix_l.csv", index_col="TrainSampleIdx")
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-14-9472f7cbb595> in <module>()
# ----> 1 df_shock_train = pd.read_csv("./data/df_shock_train_fix_l.csv", index_col="TrainSampleIdx")
#       2 df_shock_test = pd.read_csv("./data/df_shock_test_fix_l.csv", index_col="TrainSampleIdx")
#       3 df_non_shock_train = pd.read_csv("./data/df_non_shock_train_fix_l.csv", index_col="TrainSampleIdx")
#       4 df_non_shock_test = pd.read_csv("./data/df_non_shock_test_fix_l.csv", index_col="TrainSampleIdx")
#
# /home/gaoqitong/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# /home/gaoqitong/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     433
#     434     try:
# --> 435         data = parser.read(nrows)
#     436     finally:
#     437         parser.close()
#
# /home/gaoqitong/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in read(self, nrows)
#    1137     def read(self, nrows=None):
#    1138         nrows = _validate_integer('nrows', nrows)
# -> 1139         ret = self._engine.read(nrows)
#    1140
#    1141         # May alter columns / col_dict
#
# /home/gaoqitong/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in read(self, nrows)
#    2067
#    2068             names, data = self._do_date_conversions(names, data)
# -> 2069             index, names = self._make_index(data, alldata, names)
#    2070
#    2071         # maybe create a mi on the columns
#
# /home/gaoqitong/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_index(self, data, alldata, columns, indexnamerow)
#    1539
#    1540         elif not self._has_complex_date_col:
# -> 1541             index = self._get_simple_index(alldata, columns)
#    1542             index = self._agg_index(index)
#    1543         elif self._has_complex_date_col:
#
# /home/gaoqitong/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in _get_simple_index(self, data, columns)
#    1572         index = []
#    1573         for idx in self.index_col:
# -> 1574             i = ix(idx)
#    1575             to_remove.append(i)
#    1576             index.append(data[i])
#
# /home/gaoqitong/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in ix(col)
#    1567             if not isinstance(col, compat.string_types):
#    1568                 return col
# -> 1569             raise ValueError('Index %s invalid' % col)
#    1570
#    1571         to_remove = []
#
# ValueError: Index TrainSampleIdx invalid

# %%
df_shock_train = pd.read_csv("../df_all_shock_train_one_seq_per_patient.csv", index_col="TrainSampleIdx")
df_shock_test = pd.read_csv("../df_all_shock_test_one_seq_per_patient.csv", index_col="TrainSampleIdx")
df_non_shock_train = pd.read_csv("../df_all_non_shock_train_one_seq_per_patient.csv", index_col="TrainSampleIdx")
df_non_shock_test = pd.read_csv("../df_all_non_shock_test_one_seq_per_patient.csv", index_col="TrainSampleIdx")

# %%
df_shock_train = df_shock_train[[ "MinutesFromArrival", "Temperature", "RespiratoryRate", "HeartRate", "Bands", "Lactate", "WBC", "Platelet", "MAP", "SystolicBP", "FIO2", "PulseOx", "BUN", "Creatinine", "BiliRubin"]]
df_shock_test = df_shock_test[[ "MinutesFromArrival", "Temperature", "RespiratoryRate", "HeartRate", "Bands", "Lactate", "WBC", "Platelet", "MAP", "SystolicBP", "FIO2", "PulseOx", "BUN", "Creatinine", "BiliRubin"]]
df_non_shock_train = df_non_shock_train[[ "MinutesFromArrival", "Temperature", "RespiratoryRate", "HeartRate", "Bands", "Lactate", "WBC", "Platelet", "MAP", "SystolicBP", "FIO2", "PulseOx", "BUN", "Creatinine", "BiliRubin"]]
df_non_shock_test = df_non_shock_test[[ "MinutesFromArrival", "Temperature", "RespiratoryRate", "HeartRate", "Bands", "Lactate", "WBC", "Platelet", "MAP", "SystolicBP", "FIO2", "PulseOx", "BUN", "Creatinine", "BiliRubin"]]

# %%
df_shock_train = pd.concat([trun_pad(df_shock_train[df_shock_train.index==i]) for i in df_shock_train.index.unique()])
df_shock_test = pd.concat([trun_pad(df_shock_test[df_shock_test.index==i]) for i in df_shock_test.index.unique()])
df_non_shock_train = pd.concat([trun_pad(df_non_shock_train[df_non_shock_train.index==i]) for i in df_non_shock_train.index.unique()])
df_non_shock_test = pd.concat([trun_pad(df_non_shock_test[df_non_shock_test.index==i]) for i in df_non_shock_test.index.unique()])

# %%
all_df = pd.concat([df_shock_train,df_non_shock_train])

# %%
for col in df_shock_train.columns:
    df_shock_train[col] =  (df_shock_train[col] - all_df[col].mean()) / all_df[col].std()
    df_non_shock_train[col] =  (df_non_shock_train[col] - all_df[col].mean()) / all_df[col].std()
    df_shock_test[col] =  (df_shock_test[col] - all_df[col].mean()) / all_df[col].std()
    df_non_shock_test[col] =  (df_non_shock_test[col] - all_df[col].mean()) / all_df[col].std()

# %%
df_shock_train.index.name = "TrainSampleIdx"
df_shock_test.index.name = "TrainSampleIdx"
df_non_shock_train.index.name = "TrainSampleIdx"
df_non_shock_test.index.name = "TrainSampleIdx"

# %%
df_shock_train.to_csv("./data/df_shock_train_fix_l.csv")
df_shock_test.to_csv("./data/df_shock_test_fix_l.csv")
df_non_shock_train.to_csv("./data/df_non_shock_train_fix_l.csv")
df_non_shock_test.to_csv("./data/df_non_shock_test_fix_l.csv")

# %%
# determine a numerical value to represent nan values
_max = -np.infty
_min = np.infty
for _df in [df_shock_train, df_non_shock_train]:
    _df_values = np.copy(_df.values)
    _df_values[np.isnan(_df.values)] = 0.
    if np.max(_df_values) > _max:
        _max = np.max(_df_values)
    if np.min(_df_values) < _min:
        _min = np.min(_df_values)

nan_replacement = 3*_max
# nan_replacement = 0.

# %%
df_shock_train.columns = range(15)
df_shock_test.columns = range(15)
df_non_shock_train.columns = range(15)
df_non_shock_test.columns = range(15)

# %%
# determine the max sequence length
max_seq_len = -np.infty
for _df in [df_shock_train, df_non_shock_train, df_shock_test, df_non_shock_test]:
    max_for_current_df = np.max(np.unique(_df.index.values, return_counts=True)[1])
    if max_for_current_df > max_seq_len:
        max_seq_len = max_for_current_df

# %%
# replace nan values
for _df in [df_shock_train, df_non_shock_train, df_shock_test, df_non_shock_test]:
    _df[_df.isna()]=nan_replacement

# %%
def seq_length(sequence):
    used = tf.sign(tf.reduce_max(tf.abs(sequence), 2))
    length = tf.reduce_sum(used, 1)
    length = tf.cast(length, tf.int32)
    return length

# %%
def gen_train():
    # Output mask's dimensions correspond to [num_timesteps, batch_size, num_input/sequence_length]
    for i in df_shock_train.index.unique():
        current_df = df_shock_train.loc[i]
        if isinstance(current_df, pd.core.frame.DataFrame):
            current_values = df_shock_train.loc[i].values
            out = np.vstack([current_values, np.zeros((max_seq_len-current_values.shape[0], current_values.shape[1]))])
            mask = out == nan_replacement
            mask = mask.astype(np.int)
            label = np.array([0., 1.])
            yield out, label, mask
    for i in df_non_shock_train.index.unique():
        current_df = df_non_shock_train.loc[i]
        if isinstance(current_df, pd.core.frame.DataFrame):
            current_values = df_non_shock_train.loc[i].values
            out = np.vstack([current_values, np.zeros((max_seq_len-current_values.shape[0], current_values.shape[1]))])
            mask = out == nan_replacement
            mask = mask.astype(np.int)
            label = np.array([1., 0.])
            yield out, label, mask

# %%
def gen_test():
    # Output mask's dimensions correspond to [num_timesteps, batch_size, num_input/sequence_length]
    for i in df_shock_test.index.unique():
        current_df = df_shock_test.loc[i]
        if isinstance(current_df, pd.core.frame.DataFrame):
            current_values = df_shock_test.loc[i].values
            out = np.vstack([current_values, np.zeros((max_seq_len-current_values.shape[0], current_values.shape[1]))])
            mask = out == nan_replacement
            mask = mask.astype(np.int)
            label = np.array([0., 1.])
            yield out, label, mask
    for i in df_non_shock_test.index.unique():
        current_df = df_non_shock_test.loc[i]
        if isinstance(current_df, pd.core.frame.DataFrame):
            current_values = df_non_shock_test.loc[i].values
            out = np.vstack([current_values, np.zeros((max_seq_len-current_values.shape[0], current_values.shape[1]))])
            mask = out == nan_replacement
            mask = mask.astype(np.int)
            label = np.array([1., 0.])
            yield out, label, mask

# %%
import matplotlib.pyplot as plt
import scipy.stats as stats

lower, upper = 0, 1
mu, sigma = 0, 0.2
left_truncnorm = stats.truncnorm(
    (lower - mu) / sigma, (upper - mu) / sigma, loc=mu, scale=sigma)
right_truncnorm = stats.truncnorm(
    (lower - 1.) / sigma, (upper - 1.) / sigma, loc=1., scale=sigma)

fig, ax = plt.subplots(1, sharex=True)
ax.hist(np.concatenate([left_truncnorm.rvs(10000),right_truncnorm.rvs(10000)]), normed=True)
# Out:
# /home/gaoqitong/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# (array([1.96707608, 1.50105805, 0.89303454, 0.44501721, 0.19950772,
#         0.21050814, 0.43001663, 0.91603543, 1.54655981, 1.89157316]),
#  array([2.06842961e-05, 1.00016817e-01, 2.00012949e-01, 3.00009082e-01,
#         4.00005214e-01, 5.00001347e-01, 5.99997479e-01, 6.99993612e-01,
#         7.99989744e-01, 8.99985877e-01, 9.99982009e-01]),
#  <a list of 10 Patch objects>)

# %%
def train(args):
    SEED = 2599
    np.random.seed(SEED)
    tf.set_random_seed(SEED)
    random.seed(SEED)
    start_learning_rate, decay_step, decay_rate, actor_lr, critic_lr = args

    #     Training Parameters
#     start_learning_rate = 0.0005
#     decay_step = 500
#     decay_rate = 1.
    num_hidden = 1024 # hidden layer num of features

#     actor_lr = 0.0001
#     critic_lr = 0.001
    rl_reward_thres_for_decay = -20

    session_config = tf.ConfigProto(log_device_placement=False)
    session_config.gpu_options.allow_growth = True

    training_steps = 4000
    batch_size = 128

    # Network Parameters
    num_input = 15 # MIMIC data input (15 features)
    timesteps = max_seq_len # timesteps
    num_classes = 2 # MNIST total classes (0-9 digits)

    display_step = 10

    gpu = 0

    graph = tf.Graph()

    file_appendix = "MIMIC_MAXSEQLEN8_LSTMRL_MaskGradients_" + str(start_learning_rate) + "_" + str(decay_step) + "_" + str(decay_rate) + "_" + str(num_hidden) + "_" + str(actor_lr) + "_" + str(critic_lr)


    def build_net(x, is_training=True, reuse=tf.AUTO_REUSE, graph=graph):

            with graph.as_default():
                with tf.variable_scope("lstm", reuse=reuse) as scope:
                    seq_len = seq_length(x)
                    enumerated_last_idxs = tf.cast(tf.stack([seq_len-1, tf.range(tf.shape(seq_len)[0])], axis=1), tf.int32)
                    x = tf.unstack(x, timesteps, 1)
                    lstm_cell = rnn.BasicLSTMCell(num_hidden, forget_bias=1.0, reuse=reuse)
                    outputs, state, all_states = my_static_rnn(lstm_cell, x, dtype=tf.float32)
                    last_outputs = tf.gather_nd(outputs, enumerated_last_idxs)
            #         outputs = get_outputs(outputs, enumerated_seq_len)


            #             with tf.variable_scope("NN", reuse=tf.AUTO_REUSE) as scope:
                    with slim.arg_scope([slim.fully_connected], 
                                            activation_fn=tf.nn.relu,
                                            weights_initializer=tf.random_uniform_initializer(0.001, 0.01),
                                            weights_regularizer=slim.l2_regularizer(0.005),
                                            biases_regularizer=slim.l2_regularizer(0.005),
                                            normalizer_fn = slim.batch_norm,
#                                             normalizer_fn = None,
                                            normalizer_params = {"is_training": is_training},
                                            reuse = reuse,
                                            scope = scope):

            #             fc1 = slim.fully_connected(x, weights[0], scope='fc1')
            #             fc2 = slim.fully_connected(fc1, weights[1], scope='fc2')
                        logits = slim.fully_connected(last_outputs,num_classes,activation_fn=None, weights_regularizer=None, normalizer_fn=None, scope='logits')
                        pred = slim.softmax(logits, scope='pred')

                        return logits, pred, outputs, x, all_states, seq_len


    with graph.as_default():

        dataset_train = tf.data.Dataset.from_generator(gen_train, (tf.float32, tf.float32, tf.int32), ([ timesteps, 15],[ 2],[timesteps, 15])).repeat(1000).shuffle(5000).batch(batch_size)
        input_train, label_train, mask_train = dataset_train.make_one_shot_iterator().get_next()

        dataset_test = tf.data.Dataset.from_generator(gen_test, (tf.float32, tf.float32, tf.int32), ([ timesteps, 15],[ 2],[timesteps, 15])).repeat(10000).batch(len(df_shock_test.index.unique())+len(df_non_shock_test.index.unique()))
        input_test, label_test, mask_test = dataset_test.make_one_shot_iterator().get_next()

        input_train_holder = tf.placeholder(shape=[batch_size, timesteps, num_input], dtype=tf.float32)
        label_train_holder = tf.placeholder(shape=[batch_size, 2], dtype=tf.float32)
        mask_train_holder = tf.placeholder(shape=[batch_size, timesteps, num_input], dtype=tf.int32)

        logits, prediction, outs, xs, states, seq_lens = build_net(input_train_holder)
        loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=label_train_holder) + tf.reduce_mean(tf.get_collection(tf.GraphKeys.REGULARIZATION_LOSSES, scope="lstm")), axis=0)
    #         loss_op = tf.divide(tf.multiply(loss_op, max_seq_len), tf.reshape(seq_len, [-1, 1]))
        learning_rate = tf.train.exponential_decay(start_learning_rate, tf.train.get_or_create_global_step(), decay_steps=decay_step, decay_rate=decay_rate)
        optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)

        missing_idxs = tf.where_v2(mask_train)
        missing_idxs = tf.stack([missing_idxs[:,1], missing_idxs[:,0], missing_idxs[:,2]], axis=-1)

        # tensor names for <i,j,f,o> -- rnn/basic_lstm_cell/split_{}:<0,1,2,3>

        i_gates = [graph.get_tensor_by_name("lstm/rnn/basic_lstm_cell/split_"+str(t)+":0") if t>0 else graph.get_tensor_by_name("lstm/rnn/basic_lstm_cell/split:0") for t in range(timesteps)]
        j_gates = [graph.get_tensor_by_name("lstm/rnn/basic_lstm_cell/split_"+str(t)+":1") if t>0 else graph.get_tensor_by_name("lstm/rnn/basic_lstm_cell/split:1") for t in range(timesteps)]
        f_gates = [graph.get_tensor_by_name("lstm/rnn/basic_lstm_cell/split_"+str(t)+":2") if t>0 else graph.get_tensor_by_name("lstm/rnn/basic_lstm_cell/split:2") for t in range(timesteps)]
        o_gates = [graph.get_tensor_by_name("lstm/rnn/basic_lstm_cell/split_"+str(t)+":3") if t>0 else graph.get_tensor_by_name("lstm/rnn/basic_lstm_cell/split:3") for t in range(timesteps)]

        grads_i = optimizer.compute_gradients(loss_op,i_gates)
        grads_i = [g[0] for g in grads_i]
        grads_j = optimizer.compute_gradients(loss_op,j_gates)
        grads_j = [g[0] for g in grads_j]
        grads_f = optimizer.compute_gradients(loss_op,f_gates)
        grads_f = [g[0] for g in grads_f]
        grads_o = optimizer.compute_gradients(loss_op,o_gates)
        grads_o = [g[0] for g in grads_o]

        grads_i_j_f_o = [tf.concat([grads_i[t], grads_j[t], grads_f[t], grads_o[t]], axis=1) for t in range(timesteps)]

    #     xs_need_to_be_zero = tf.gather_nd(xs,missing_idxs)
    #     xs_updates = tf.scatter_nd(indices=missing_idxs, updates=-xs_need_to_be_zero, shape=[timesteps, batch_size, num_input])
    #     xs_for_grads = xs + xs_updates
        grad_attention = tf.placeholder(shape=[timesteps, batch_size, num_input], dtype=tf.float32)
        xs_for_grads = tf.multiply(xs, grad_attention)
        W_grads = tf.tensordot(xs_for_grads, grads_i_j_f_o, axes=[[0,1],[0,1]])/batch_size

        enumerated_seq_lens = tf.cast(tf.stack([seq_lens, tf.range(tf.shape(seq_lens)[0])], axis=1), tf.int32)

        def cond(i, e, o):
            return i < batch_size
        def body(i, e, o):
            o = tf.concat([o,tf.stack([tf.range(e[i,0]),tf.repeat(e[i,1],e[i,0])],axis=-1)],axis=0)
            return i+1, e, o

        _,_,nonzero_out_idxs = tf.while_loop(cond,body,[tf.constant(1, dtype=tf.int32), enumerated_seq_lens, tf.stack([tf.range(enumerated_seq_lens[0,0]),tf.repeat(enumerated_seq_lens[0,1],enumerated_seq_lens[0,0])],axis=-1)], shape_invariants=[tf.TensorShape([]),tf.TensorShape([None,2]),tf.TensorShape([None,2])])

        outs_non_zero = tf.gather_nd(outs,nonzero_out_idxs)
        outs_updates = tf.scatter_nd(indices=nonzero_out_idxs, updates=outs_non_zero, shape=[timesteps, batch_size, num_hidden])
        outs = tf.zeros((timesteps,batch_size,num_hidden)) + outs_updates
        U_grads = tf.tensordot(outs, grads_i_j_f_o, axes=[[0,1],[0,1]])/batch_size
        lstm_kernel_grads = tf.concat([W_grads,U_grads],axis=0)     

        logits_final, pred_final, _, _, _, _ = build_net(input_test, is_training=False)


        grads = optimizer.compute_gradients(loss_op, [v for v in tf.trainable_variables() if v.name.find("lstm")!=-1])
        grads = [g[0] for g in grads]

        grads[0] = lstm_kernel_grads


        grads_update_op = optimizer.apply_gradients(zip(grads, [v for v in tf.trainable_variables() if v.name.find("lstm")!=-1]))

        train_correct_pred = tf.equal(tf.cast(tf.argmax(prediction, 1),tf.float32), tf.cast(tf.argmax(label_train_holder, 1),tf.float32) )
        train_accuracy = tf.reduce_mean(tf.cast(train_correct_pred, tf.float32))
        train_kld = tf.keras.losses.KLDivergence()(prediction, label_train_holder)

        final_correct_pred = tf.equal(tf.cast(tf.argmax(pred_final, 1), tf.float32), tf.cast(tf.argmax(label_test, 1),tf.float32))
        final_accuracy = tf.reduce_mean(tf.cast(final_correct_pred, tf.float32))
        final_kld = tf.keras.losses.KLDivergence()(pred_final, label_test)

        final_score = pred_final[:,1]

        max_final_acc = tf.Variable(0, dtype=tf.float32, name="max_final_acc", trainable=False)
        assign_max_final_acc = max_final_acc.assign(final_accuracy)

    with graph.as_default():
        actor = Actor(graph=graph, state_dim=num_input*2+num_hidden*2, action_dim=num_input, learning_rate=actor_lr, tau=0.001, batch_size=batch_size, save_path="./saved_model/"+file_appendix+"/actor.ckpt")
        critic = Critic(graph=graph, state_dim=num_input*2+num_hidden*2, action_dim=num_input, learning_rate=critic_lr, tau=0.001, gamma=0.99, save_path="./saved_model/"+file_appendix+"/critic.ckpt")
        init = tf.global_variables_initializer()
        saver = tf.train.Saver()


    # Start training
    with tf.Session(config=session_config, graph=graph) as sess:
        sess.run(init)
        EXPLORATION_RATE = 0.6
        GUIDE_RATE = 0.15
        ep_reward = 0
        ep_ave_max_q = 0

        data_in, label_in, s_mask = sess.run([input_train, label_train, mask_train])


        s_1, s_2 = sess.run([states, outs], feed_dict = {input_train_holder:data_in, label_train_holder:label_in, mask_train_holder:s_mask})
        s = np.concatenate([np.asarray(np.split(data_in,timesteps,axis=1)).reshape(timesteps,batch_size,num_input),
                       np.asarray(np.split(s_mask,timesteps,axis=1)).reshape(timesteps,batch_size,num_input)
                            ,s_1,s_2], axis=-1)


        reward_list = []
        ave_max_q_list = []
        replay_buffer = ReplayBuffer(10**5, random_seed=SEED)

        # Run the initializer


        max_auc = 0.
        max_ap = 0.

        actor.update_target_network(sess)
        critic.update_target_network(sess)

        for step in range(training_steps):
            rand_num = np.random.rand(1)

            if rand_num <= EXPLORATION_RATE:
                a = np.concatenate([left_truncnorm.rvs(timesteps*batch_size*num_input/2),right_truncnorm.rvs(timesteps*batch_size*num_input/2)])
                np.random.shuffle(a)
                a = a.reshape(timesteps, batch_size, num_input).astype(np.float32)

            elif rand_num <= GUIDE_RATE+EXPLORATION_RATE and rand_num > EXPLORATION_RATE:
                a = np.asarray(np.split((1-s_mask).astype(np.float32), timesteps, axis=1)).reshape(timesteps,batch_size,num_input)

            else:
                a = actor.predict(s.reshape(-1,num_input*2+num_hidden*2), sess)
                a = a.reshape(timesteps, batch_size, num_input)
#                 print "a: ", a
#                 print "mask: ", s_mask

            _, kld = sess.run([grads_update_op, train_kld], feed_dict={grad_attention:a, input_train_holder:data_in, label_train_holder:label_in, mask_train_holder:s_mask})
            acc, score = sess.run([final_accuracy, final_score])
            data_in, label_in, s2_mask = sess.run([input_train, label_train, mask_train])
            s2_1, s2_2 = sess.run([states, outs], feed_dict = {input_train_holder:data_in, label_train_holder:label_in})
            s2 = np.concatenate([np.asarray(np.split(data_in,timesteps,axis=1)).reshape(timesteps,batch_size,num_input),
                       np.asarray(np.split(s_mask,timesteps,axis=1)).reshape(timesteps,batch_size,num_input)
                            ,s2_1,s2_2], axis=-1)
    #         auc = roc_auc_score(sess.run(label_test), score)
    #         ap = average_precision_score(sess.run(label_test), score)
    #         r = np.repeat(acc + auc + ap - 3., batch_size)
            r = np.repeat(-kld, batch_size)
            replay_buffer.add_batch([list(i) for i in zip(s.reshape(-1,num_input*2+num_hidden*2),a.reshape(-1,num_input),r,s2.reshape(-1,num_input*2+num_hidden*2))])

            if replay_buffer.size() > batch_size:
                s_batch, a_batch, r_batch, s2_batch = replay_buffer.sample_batch(batch_size)

                # Calculate targets
                target_q = critic.predict_target(
                    s2_batch, actor.predict_target(s2_batch, sess), sess)

                y_i = []
                for k in range(batch_size):
                    y_i.append(r_batch[k] + critic.gamma * target_q[k])

                # Update the critic given the targets
                predicted_q_value, _ = critic.train(
                    s_batch, a_batch, np.reshape(y_i, (batch_size, 1)), step, sess)

                ave_max_q = np.amax(predicted_q_value)
                ave_max_q_list += [ave_max_q]

                # Update the actor policy using the sampled gradient
                a_outs = actor.predict(s_batch, sess)
                grads = critic.action_gradients(s_batch, a_outs, sess)
                actor.train(s_batch, grads[0], step, sess)

                # Update target networks
                actor.update_target_network(sess)
                critic.update_target_network(sess)

            s = s2
            s_mask = s2_mask

            reward_list += [r[0]]
            
            EXPLORATION_RATE = EXPLORATION_RATE * 0.995
            GUIDE_RATE = GUIDE_RATE * 0.995


            if step % display_step == 0 and step > 0:
                # Calculate batch loss and accuracy
                loss, acc, train_acc = sess.run([loss_op, final_accuracy, train_accuracy], feed_dict = {input_train_holder:data_in, label_train_holder:label_in})
                auc = roc_auc_score(np.argmax(sess.run(label_test), axis=1), final_score.eval())
                ap = average_precision_score(np.argmax(sess.run(label_test), axis=1), final_score.eval())
                if np.mean(reward_list[-display_step:]) >= rl_reward_thres_for_decay:
                    actor.decay_learning_rate(0.965, sess)
                    critic.decay_learning_rate(0.965, sess)
                if acc > max_final_acc.eval():
                    max_auc = auc
                    max_ap = ap
                    sess.run(assign_max_final_acc)
                    saver.save(sess, "./saved_model/"+file_appendix+"/best.ckpt")
                print "Step " + str(step) + ", Reward=" + str(np.sum(reward_list[-display_step:])) + ", Minibatch Loss= " + \
                      "{:.4f}".format(loss) + ", Training Accuracy= " + \
                      "{:.3f}".format(train_acc) + ", Testing Acc= " + "{:3f}".format(final_accuracy.eval()) + \
                      ", Max Final Accuracy= ", "{:6f}".format(max_final_acc.eval()) + \
                      ", Max AUC= ", "{:6f}".format(max_auc) + \
                      ", Max AP= ", "{:6f}".format(max_ap) + \
                      ", Max Q= ", "{:6f}".format(np.mean(ave_max_q_list[-display_step:]))
                with open("./stats/rl_log/" + file_appendix + ".txt", "ab") as myfile:
                    myfile.write("Step " + str(step) + ", Reward=" + str(np.sum(reward_list[-display_step:])) + ", Minibatch Loss= " + "{:.4f}".format(loss) + ", Training Accuracy= " + "{:.3f}".format(train_acc) + ", Testing Acc= " + "{:3f}".format(final_accuracy.eval()) + ", Max Final Accuracy= " + "{:6f}".format(max_final_acc.eval()) + ", Max AUC= " + "{:6f}".format(max_auc) + ", Max AP= " + "{:6f}".format(max_ap) + "\n")

        print "Optimization Finished!"

        print "Testing Accuracy:", sess.run(max_final_acc)
        with open("./stats/MIMIC_MAXSEQLEN8_LSTMRL_maskGradients.txt", "ab") as myfile:
            myfile.write("%.6f\t%i\t%.3f\t%.6f\t%.6f\t%i\t%.6f\t%.6f\t%.6f\n" %(start_learning_rate, decay_step, decay_rate, actor_lr, critic_lr, num_hidden, max_final_acc.eval(), max_auc, max_ap))

# %%
LRs = [0.00101, 0.000701, 0.000501, 0.000301, 0.000101]
DSs = [1000, 500, 150]
DRs = [.95, .85, .75]
ACTORs = [0.0001001, 0.0005001, 0.00005001]
CRITICs = [0.0005001, 0.0001001]
# ACTORs = [0.0005001]
# CRITICs = [0.0001001]

pool = mp.Pool(6)
pool.map(train, [(lr, ds, dr, a_lr, c_lr) for lr in LRs for ds in DSs for dr in DRs for a_lr in ACTORs for c_lr in CRITICs])
pool.close()
pool.join()
# Out:
# W0511 00:23:37.199004 140396203640640 deprecation.py:323] From <ipython-input-16-47bc1f99152b>:74: make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# W0511 00:23:37.207410 140396203640640 deprecation.py:323] From <ipython-input-16-47bc1f99152b>:74: make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# W0511 00:23:37.209749 140396203640640 deprecation.py:323] From <ipython-input-16-47bc1f99152b>:74: make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# W0511 00:23:37.211981 140396203640640 deprecation.py:323] From <ipython-input-16-47bc1f99152b>:74: make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# W0511 00:23:37.213749 140396203640640 deprecation.py:323] From <ipython-input-16-47bc1f99152b>:74: make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# W0511 00:23:37.218056 140396203640640 deprecation.py:323] From <ipython-input-16-47bc1f99152b>:74: make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# W0511 00:23:37.306380 140396203640640 deprecation.py:323] From <ipython-input-16-47bc1f99152b>:45: __init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# W0511 00:23:37.316320 140396203640640 deprecation.py:323] From <ipython-input-16-47bc1f99152b>:45: __init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# W0511 00:23:37.319659 140396203640640 deprecation.py:323] From <ipython-input-16-47bc1f99152b>:45: __init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# W0511 00:23:37.325615 140396203640640 deprecation.py:323] From <ipython-input-16-47bc1f99152b>:45: __init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# W0511 00:23:37.321602 140396203640640 deprecation.py:323] From <ipython-input-16-47bc1f99152b>:45: __init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# W0511 00:23:37.326630 140396203640640 deprecation.py:323] From <ipython-input-16-47bc1f99152b>:45: __init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# W0511 00:23:37.335724 140396203640640 deprecation.py:323] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:735: add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# W0511 00:23:37.339093 140396203640640 deprecation.py:323] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:735: add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# W0511 00:23:37.343492 140396203640640 deprecation.py:323] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:735: add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# W0511 00:23:37.349076 140396203640640 deprecation.py:323] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:735: add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# W0511 00:23:37.356272 140396203640640 deprecation.py:323] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:735: add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# W0511 00:23:37.354214 140396203640640 deprecation.py:506] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:739: calling __init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0511 00:23:37.350354 140396203640640 deprecation.py:323] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:735: add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# W0511 00:23:37.362263 140396203640640 deprecation.py:506] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:739: calling __init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0511 00:23:37.365283 140396203640640 deprecation.py:506] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:739: calling __init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0511 00:23:37.364116 140396203640640 deprecation.py:506] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:739: calling __init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0511 00:23:37.374027 140396203640640 deprecation.py:506] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:739: calling __init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0511 00:23:37.376703 140396203640640 deprecation.py:506] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:739: calling __init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0511 00:23:37.506252 140396203640640 deprecation.py:323] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1866: apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0511 00:23:37.510272 140396203640640 deprecation.py:323] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1866: apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0511 00:23:37.509035 140396203640640 deprecation.py:323] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1866: apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0511 00:23:37.513025 140396203640640 deprecation.py:323] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1866: apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0511 00:23:37.521629 140396203640640 deprecation.py:323] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1866: apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0511 00:23:37.535559 140396203640640 deprecation.py:323] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1866: apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0511 00:23:37.543143 140396203640640 deprecation.py:323] From <ipython-input-16-47bc1f99152b>:84: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0511 00:23:37.547619 140396203640640 deprecation.py:323] From <ipython-input-16-47bc1f99152b>:84: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0511 00:23:37.548135 140396203640640 deprecation.py:323] From <ipython-input-16-47bc1f99152b>:84: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0511 00:23:37.553040 140396203640640 deprecation.py:323] From <ipython-input-16-47bc1f99152b>:84: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0511 00:23:37.554131 140396203640640 deprecation.py:323] From <ipython-input-16-47bc1f99152b>:84: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0511 00:23:37.570084 140396203640640 deprecation.py:323] From <ipython-input-16-47bc1f99152b>:84: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0511 00:23:41.051309 140396203640640 deprecation.py:323] From qnetwork.py:37: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W0511 00:23:41.087119 140396203640640 deprecation.py:323] From qnetwork.py:37: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W0511 00:23:41.100279 140396203640640 deprecation.py:323] From qnetwork.py:37: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W0511 00:23:41.129945 140396203640640 deprecation.py:323] From qnetwork.py:37: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W0511 00:23:41.177557 140396203640640 module_wrapper.py:139] From qnetwork.py:47: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0511 00:23:41.215352 140396203640640 module_wrapper.py:139] From qnetwork.py:47: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0511 00:23:41.213687 140396203640640 deprecation.py:323] From qnetwork.py:37: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W0511 00:23:41.227845 140396203640640 module_wrapper.py:139] From qnetwork.py:47: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0511 00:23:41.237602 140396203640640 deprecation.py:323] From qnetwork.py:37: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W0511 00:23:41.257210 140396203640640 module_wrapper.py:139] From qnetwork.py:47: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0511 00:23:41.335764 140396203640640 module_wrapper.py:139] From qnetwork.py:47: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
# W0511 00:23:41.381737 140396203640640 module_wrapper.py:139] From qnetwork.py:47: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0511 00:23:41.743710 140396203640640 module_wrapper.py:139] From qnetwork.py:137: The name tf.losses.mean_squared_error is deprecated. Please use tf.compat.v1.losses.mean_squared_error instead.
#
# W0511 00:23:41.749439 140396203640640 module_wrapper.py:139] From qnetwork.py:137: The name tf.losses.mean_squared_error is deprecated. Please use tf.compat.v1.losses.mean_squared_error instead.
#
# W0511 00:23:41.767817 140396203640640 deprecation.py:323] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0511 00:23:41.742672 140396203640640 module_wrapper.py:139] From qnetwork.py:137: The name tf.losses.mean_squared_error is deprecated. Please use tf.compat.v1.losses.mean_squared_error instead.
#
# W0511 00:23:41.773267 140396203640640 deprecation.py:323] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0511 00:23:41.790242 140396203640640 module_wrapper.py:139] From qnetwork.py:137: The name tf.losses.mean_squared_error is deprecated. Please use tf.compat.v1.losses.mean_squared_error instead.
#
# W0511 00:23:41.805993 140396203640640 deprecation.py:323] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0511 00:23:41.785630 140396203640640 deprecation.py:323] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0511 00:23:41.872848 140396203640640 module_wrapper.py:139] From qnetwork.py:137: The name tf.losses.mean_squared_error is deprecated. Please use tf.compat.v1.losses.mean_squared_error instead.
#
# W0511 00:23:41.890944 140396203640640 deprecation.py:323] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0511 00:23:41.951549 140396203640640 module_wrapper.py:139] From qnetwork.py:137: The name tf.losses.mean_squared_error is deprecated. Please use tf.compat.v1.losses.mean_squared_error instead.
#
# W0511 00:23:41.970931 140396203640640 deprecation.py:323] From /home/gaoqitong/anaconda2/lib/python2.7/site-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Step 10, Reward=-40.994637, Minibatch Loss= 0.3234, Training Accuracy= 0.891, Testing Acc= 0.861751, Max Final Accuracy=  0.861751, Max AUC=  0.905116, Max AP=  0.876578, Max Q=  -0.258764
# Step 10, Reward=-40.994637, Minibatch Loss= 0.3234, Training Accuracy= 0.891, Testing Acc= 0.861751, Max Final Accuracy=  0.861751, Max AUC=  0.905116, Max AP=  0.876578, Max Q=  -0.258764
# Step 10, Reward=-40.994637, Minibatch Loss= 0.3234, Training Accuracy= 0.891, Testing Acc= 0.861751, Max Final Accuracy=  0.861751, Max AUC=  0.905116, Max AP=  0.876578, Max Q=  -0.258764
# Step 10, Reward=-40.994637, Minibatch Loss= 0.3234, Training Accuracy= 0.891, Testing Acc= 0.861751, Max Final Accuracy=  0.861751, Max AUC=  0.905116, Max AP=  0.876578, Max Q=  -0.258764
# Step 10, Reward=-40.994637, Minibatch Loss= 0.3234, Training Accuracy= 0.891, Testing Acc= 0.861751, Max Final Accuracy=  0.861751, Max AUC=  0.905116, Max AP=  0.876578, Max Q=  -0.258764
# Step 10, Reward=-44.673447, Minibatch Loss= 0.3302, Training Accuracy= 0.891, Testing Acc= 0.861751, Max Final Accuracy=  0.861751, Max AUC=  0.898607, Max AP=  0.863513, Max Q=  -0.264655
# Step 20, Reward=-28.529713, Minibatch Loss= 0.3337, Training Accuracy= 0.875, Testing Acc= 0.866359, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -0.501849
# Step 20, Reward=-28.529705, Minibatch Loss= 0.3337, Training Accuracy= 0.875, Testing Acc= 0.866359, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -0.501850
# Step 20, Reward=-28.529728, Minibatch Loss= 0.3337, Training Accuracy= 0.875, Testing Acc= 0.866359, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -0.501849
# Step 20, Reward=-28.529694, Minibatch Loss= 0.3337, Training Accuracy= 0.875, Testing Acc= 0.866359, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -0.501849
# Step 20, Reward=-28.160896, Minibatch Loss= 0.3421, Training Accuracy= 0.875, Testing Acc= 0.861751, Max Final Accuracy=  0.861751, Max AUC=  0.898607, Max AP=  0.863513, Max Q=  -0.514561
# Step 20, Reward=-28.529713, Minibatch Loss= 0.3337, Training Accuracy= 0.875, Testing Acc= 0.866359, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -0.501850
# Step 30, Reward=-32.86454, Minibatch Loss= 0.3121, Training Accuracy= 0.906, Testing Acc= 0.864055, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -0.907086
# Step 30, Reward=-32.850117, Minibatch Loss= 0.3122, Training Accuracy= 0.906, Testing Acc= 0.864055, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -0.907075
# Step 30, Reward=-32.860256, Minibatch Loss= 0.3121, Training Accuracy= 0.906, Testing Acc= 0.864055, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -0.907081
# Step 30, Reward=-32.865078, Minibatch Loss= 0.3121, Training Accuracy= 0.906, Testing Acc= 0.864055, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -0.907086
# Step 30, Reward=-32.861656, Minibatch Loss= 0.3122, Training Accuracy= 0.906, Testing Acc= 0.864055, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -0.907068
# Step 30, Reward=-32.60352, Minibatch Loss= 0.3323, Training Accuracy= 0.867, Testing Acc= 0.866359, Max Final Accuracy=  0.866359, Max AUC=  0.917199, Max AP=  0.890953, Max Q=  -0.824778
# Step 40, Reward=-28.85271, Minibatch Loss= 0.3262, Training Accuracy= 0.859, Testing Acc= 0.859447, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.410445
# Step 40, Reward=-28.840984, Minibatch Loss= 0.3259, Training Accuracy= 0.859, Testing Acc= 0.857143, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.410029
# Step 40, Reward=-28.853333, Minibatch Loss= 0.3265, Training Accuracy= 0.859, Testing Acc= 0.857143, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.410171
# Step 40, Reward=-28.847126, Minibatch Loss= 0.3263, Training Accuracy= 0.859, Testing Acc= 0.857143, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.410308
# Step 40, Reward=-28.853937, Minibatch Loss= 0.3262, Training Accuracy= 0.859, Testing Acc= 0.857143, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.410167
# Step 40, Reward=-29.808218, Minibatch Loss= 0.3310, Training Accuracy= 0.852, Testing Acc= 0.859447, Max Final Accuracy=  0.866359, Max AUC=  0.917199, Max AP=  0.890953, Max Q=  -1.394289
# Step 50, Reward=-30.081175, Minibatch Loss= 0.3501, Training Accuracy= 0.875, Testing Acc= 0.864055, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.372876
# Step 50, Reward=-30.165146, Minibatch Loss= 0.3512, Training Accuracy= 0.883, Testing Acc= 0.864055, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.373268
# Step 50, Reward=-30.174746, Minibatch Loss= 0.3491, Training Accuracy= 0.875, Testing Acc= 0.864055, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.373052
# Step 50, Reward=-30.180119, Minibatch Loss= 0.3495, Training Accuracy= 0.875, Testing Acc= 0.864055, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.373243
# Step 50, Reward=-30.162859, Minibatch Loss= 0.3482, Training Accuracy= 0.883, Testing Acc= 0.864055, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.372535
# Step 50, Reward=-30.641695, Minibatch Loss= 0.3314, Training Accuracy= 0.891, Testing Acc= 0.864055, Max Final Accuracy=  0.866359, Max AUC=  0.917199, Max AP=  0.890953, Max Q=  -1.349561
# Step 60, Reward=-28.687809, Minibatch Loss= 0.2942, Training Accuracy= 0.883, Testing Acc= 0.864055, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.580625
# Step 60, Reward=-28.650858, Minibatch Loss= 0.2937, Training Accuracy= 0.883, Testing Acc= 0.866359, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.581531
# Step 60, Reward=-28.754522, Minibatch Loss= 0.2969, Training Accuracy= 0.883, Testing Acc= 0.866359, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.579492
# Step 60, Reward=-28.661032, Minibatch Loss= 0.2954, Training Accuracy= 0.883, Testing Acc= 0.861751, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.577728
# Step 60, Reward=-28.60517, Minibatch Loss= 0.2955, Training Accuracy= 0.883, Testing Acc= 0.868664, Max Final Accuracy=  0.868664, Max AUC=  0.933127, Max AP=  0.917078, Max Q=  -1.577287
# Step 60, Reward=-28.801516, Minibatch Loss= 0.3053, Training Accuracy= 0.883, Testing Acc= 0.875576, Max Final Accuracy=  0.875576, Max AUC=  0.928731, Max AP=  0.906399, Max Q=  -1.678158
# Step 70, Reward=-29.389484, Minibatch Loss= 0.2623, Training Accuracy= 0.906, Testing Acc= 0.864055, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.681075
# Step 70, Reward=-29.465582, Minibatch Loss= 0.2531, Training Accuracy= 0.906, Testing Acc= 0.866359, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.689917
# Step 70, Reward=-29.388052, Minibatch Loss= 0.2550, Training Accuracy= 0.906, Testing Acc= 0.864055, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.667095
# Step 70, Reward=-29.461155, Minibatch Loss= 0.2556, Training Accuracy= 0.906, Testing Acc= 0.868664, Max Final Accuracy=  0.868664, Max AUC=  0.931598, Max AP=  0.918272, Max Q=  -1.677296
# Step 70, Reward=-29.384546, Minibatch Loss= 0.2552, Training Accuracy= 0.906, Testing Acc= 0.866359, Max Final Accuracy=  0.868664, Max AUC=  0.933127, Max AP=  0.917078, Max Q=  -1.676387
# Step 70, Reward=-29.263908, Minibatch Loss= 0.2541, Training Accuracy= 0.906, Testing Acc= 0.861751, Max Final Accuracy=  0.875576, Max AUC=  0.928731, Max AP=  0.906399, Max Q=  -1.657473
# Step 80, Reward=-24.933586, Minibatch Loss= 0.2733, Training Accuracy= 0.883, Testing Acc= 0.866359, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.762599
# Step 80, Reward=-25.23128, Minibatch Loss= 0.2714, Training Accuracy= 0.883, Testing Acc= 0.866359, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.761920
# Step 80, Reward=-25.022663, Minibatch Loss= 0.2712, Training Accuracy= 0.891, Testing Acc= 0.866359, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.758019
# Step 80, Reward=-25.023605, Minibatch Loss= 0.2744, Training Accuracy= 0.883, Testing Acc= 0.866359, Max Final Accuracy=  0.868664, Max AUC=  0.931598, Max AP=  0.918272, Max Q=  -1.756576
# Step 80, Reward=-25.036913, Minibatch Loss= 0.2691, Training Accuracy= 0.875, Testing Acc= 0.866359, Max Final Accuracy=  0.868664, Max AUC=  0.933127, Max AP=  0.917078, Max Q=  -1.759339
# Step 80, Reward=-24.705303, Minibatch Loss= 0.2670, Training Accuracy= 0.875, Testing Acc= 0.866359, Max Final Accuracy=  0.875576, Max AUC=  0.928731, Max AP=  0.906399, Max Q=  -1.711312
# Step 90, Reward=-27.38192, Minibatch Loss= 0.2798, Training Accuracy= 0.883, Testing Acc= 0.864055, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.746641
# Step 90, Reward=-27.390528, Minibatch Loss= 0.2838, Training Accuracy= 0.875, Testing Acc= 0.866359, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.770468
# Step 90, Reward=-27.373363, Minibatch Loss= 0.2911, Training Accuracy= 0.875, Testing Acc= 0.866359, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.764804
# Step 90, Reward=-27.514774, Minibatch Loss= 0.2885, Training Accuracy= 0.875, Testing Acc= 0.859447, Max Final Accuracy=  0.868664, Max AUC=  0.931598, Max AP=  0.918272, Max Q=  -1.770128
# Step 90, Reward=-27.239141, Minibatch Loss= 0.2873, Training Accuracy= 0.883, Testing Acc= 0.861751, Max Final Accuracy=  0.868664, Max AUC=  0.933127, Max AP=  0.917078, Max Q=  -1.772142
# Step 90, Reward=-27.386845, Minibatch Loss= 0.2706, Training Accuracy= 0.898, Testing Acc= 0.859447, Max Final Accuracy=  0.875576, Max AUC=  0.928731, Max AP=  0.906399, Max Q=  -1.751961
# Step 100, Reward=-29.003325, Minibatch Loss= 0.4031, Training Accuracy= 0.844, Testing Acc= 0.859447, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.757177
# Step 100, Reward=-28.546028, Minibatch Loss= 0.4070, Training Accuracy= 0.844, Testing Acc= 0.861751, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.792398
# Step 100, Reward=-28.8468, Minibatch Loss= 0.4061, Training Accuracy= 0.852, Testing Acc= 0.861751, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.775007
# Step 100, Reward=-28.967392, Minibatch Loss= 0.4035, Training Accuracy= 0.844, Testing Acc= 0.861751, Max Final Accuracy=  0.868664, Max AUC=  0.931598, Max AP=  0.918272, Max Q=  -1.793791
# Step 100, Reward=-28.614185, Minibatch Loss= 0.4054, Training Accuracy= 0.844, Testing Acc= 0.859447, Max Final Accuracy=  0.868664, Max AUC=  0.933127, Max AP=  0.917078, Max Q=  -1.794915
# Step 100, Reward=-28.797033, Minibatch Loss= 0.3973, Training Accuracy= 0.852, Testing Acc= 0.864055, Max Final Accuracy=  0.875576, Max AUC=  0.928731, Max AP=  0.906399, Max Q=  -1.823157
# Step 110, Reward=-29.40843, Minibatch Loss= 0.2932, Training Accuracy= 0.898, Testing Acc= 0.866359, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.793533
# Step 110, Reward=-30.179216, Minibatch Loss= 0.2974, Training Accuracy= 0.898, Testing Acc= 0.861751, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.819155
# Step 110, Reward=-29.492155, Minibatch Loss= 0.3090, Training Accuracy= 0.859, Testing Acc= 0.854839, Max Final Accuracy=  0.866359, Max AUC=  0.904649, Max AP=  0.873779, Max Q=  -1.837203
# Step 110, Reward=-29.429483, Minibatch Loss= 0.2893, Training Accuracy= 0.914, Testing Acc= 0.861751, Max Final Accuracy=  0.868664, Max AUC=  0.931598, Max AP=  0.918272, Max Q=  -1.826910
# Step 110, Reward=-29.454165, Minibatch Loss= 0.2993, Training Accuracy= 0.898, Testing Acc= 0.861751, Max Final Accuracy=  0.868664, Max AUC=  0.933127, Max AP=  0.917078, Max Q=  -1.821801
# Step 110, Reward=-29.3973, Minibatch Loss= 0.2961, Training Accuracy= 0.891, Testing Acc= 0.866359, Max Final Accuracy=  0.875576, Max AUC=  0.928731, Max AP=  0.906399, Max Q=  -1.793595
# Step 120, Reward=-27.282324, Minibatch Loss= 0.2750, Training Accuracy= 0.867, Testing Acc= 0.870968, Max Final Accuracy=  0.870968, Max AUC=  0.927945, Max AP=  0.909612, Max Q=  -1.764256
# Step 120, Reward=-27.455551, Minibatch Loss= 0.2664, Training Accuracy= 0.883, Testing Acc= 0.870968, Max Final Accuracy=  0.870968, Max AUC=  0.930451, Max AP=  0.911981, Max Q=  -1.764553
# Step 120, Reward=-27.603971, Minibatch Loss= 0.2662, Training Accuracy= 0.875, Testing Acc= 0.873272, Max Final Accuracy=  0.873272, Max AUC=  0.935293, Max AP=  0.920720, Max Q=  -1.762495
# Step 120, Reward=-27.570738, Minibatch Loss= 0.2721, Training Accuracy= 0.875, Testing Acc= 0.868664, Max Final Accuracy=  0.868664, Max AUC=  0.931598, Max AP=  0.918272, Max Q=  -1.749648
# Step 120, Reward=-27.724646, Minibatch Loss= 0.2706, Training Accuracy= 0.867, Testing Acc= 0.870968, Max Final Accuracy=  0.870968, Max AUC=  0.927350, Max AP=  0.904598, Max Q=  -1.756479
# Step 120, Reward=-27.360626, Minibatch Loss= 0.2728, Training Accuracy= 0.859, Testing Acc= 0.873272, Max Final Accuracy=  0.875576, Max AUC=  0.928731, Max AP=  0.906399, Max Q=  -1.795948
# Step 130, Reward=-29.733967, Minibatch Loss= 0.3836, Training Accuracy= 0.836, Testing Acc= 0.868664, Max Final Accuracy=  0.870968, Max AUC=  0.927945, Max AP=  0.909612, Max Q=  -1.831251
# Step 130, Reward=-29.151773, Minibatch Loss= 0.3804, Training Accuracy= 0.836, Testing Acc= 0.864055, Max Final Accuracy=  0.870968, Max AUC=  0.930451, Max AP=  0.911981, Max Q=  -1.845976
# Step 130, Reward=-29.290802, Minibatch Loss= 0.3773, Training Accuracy= 0.836, Testing Acc= 0.864055, Max Final Accuracy=  0.873272, Max AUC=  0.935293, Max AP=  0.920720, Max Q=  -1.812444
# Step 130, Reward=-29.881132, Minibatch Loss= 0.3731, Training Accuracy= 0.859, Testing Acc= 0.859447, Max Final Accuracy=  0.868664, Max AUC=  0.931598, Max AP=  0.918272, Max Q=  -1.831116
# Step 130, Reward=-29.451235, Minibatch Loss= 0.3669, Training Accuracy= 0.844, Testing Acc= 0.861751, Max Final Accuracy=  0.870968, Max AUC=  0.927350, Max AP=  0.904598, Max Q=  -1.860481
# Step 130, Reward=-29.750706, Minibatch Loss= 0.3805, Training Accuracy= 0.828, Testing Acc= 0.866359, Max Final Accuracy=  0.875576, Max AUC=  0.928731, Max AP=  0.906399, Max Q=  -1.769123
# Step 140, Reward=-27.958452, Minibatch Loss= 0.2902, Training Accuracy= 0.898, Testing Acc= 0.864055, Max Final Accuracy=  0.870968, Max AUC=  0.927945, Max AP=  0.909612, Max Q=  -1.864498
# Step 140, Reward=-27.800808, Minibatch Loss= 0.2888, Training Accuracy= 0.898, Testing Acc= 0.868664, Max Final Accuracy=  0.870968, Max AUC=  0.930451, Max AP=  0.911981, Max Q=  -1.867740
# Step 140, Reward=-27.784, Minibatch Loss= 0.2909, Training Accuracy= 0.891, Testing Acc= 0.861751, Max Final Accuracy=  0.873272, Max AUC=  0.935293, Max AP=  0.920720, Max Q=  -1.851883
# Step 140, Reward=-28.294567, Minibatch Loss= 0.2917, Training Accuracy= 0.898, Testing Acc= 0.864055, Max Final Accuracy=  0.868664, Max AUC=  0.931598, Max AP=  0.918272, Max Q=  -1.884867
# Step 140, Reward=-28.213703, Minibatch Loss= 0.2920, Training Accuracy= 0.898, Testing Acc= 0.868664, Max Final Accuracy=  0.870968, Max AUC=  0.927350, Max AP=  0.904598, Max Q=  -1.891221
# Step 140, Reward=-27.965559, Minibatch Loss= 0.2864, Training Accuracy= 0.891, Testing Acc= 0.861751, Max Final Accuracy=  0.875576, Max AUC=  0.928731, Max AP=  0.906399, Max Q=  -1.848017
# Step 150, Reward=-26.457045, Minibatch Loss= 0.3725, Training Accuracy= 0.867, Testing Acc= 0.870968, Max Final Accuracy=  0.873272, Max AUC=  0.935293, Max AP=  0.920720, Max Q=  -1.834482
# Step 150, Reward=-26.642168, Minibatch Loss= 0.3814, Training Accuracy= 0.867, Testing Acc= 0.873272, Max Final Accuracy=  0.873272, Max AUC=  0.936270, Max AP=  0.919574, Max Q=  -1.823994
# Step 150, Reward=-26.303183, Minibatch Loss= 0.3747, Training Accuracy= 0.891, Testing Acc= 0.880184, Max Final Accuracy=  0.880184, Max AUC=  0.937523, Max AP=  0.919009, Max Q=  -1.828288
# Step 150, Reward=-26.953365, Minibatch Loss= 0.3844, Training Accuracy= 0.867, Testing Acc= 0.873272, Max Final Accuracy=  0.873272, Max AUC=  0.937969, Max AP=  0.920631, Max Q=  -1.825680
# Step 150, Reward=-26.513706, Minibatch Loss= 0.3793, Training Accuracy= 0.867, Testing Acc= 0.884793, Max Final Accuracy=  0.884793, Max AUC=  0.934019, Max AP=  0.913224, Max Q=  -1.846048
# Step 150, Reward=-26.588352, Minibatch Loss= 0.3784, Training Accuracy= 0.875, Testing Acc= 0.873272, Max Final Accuracy=  0.875576, Max AUC=  0.928731, Max AP=  0.906399, Max Q=  -1.887299
# Step 160, Reward=-28.111494, Minibatch Loss= 0.2549, Training Accuracy= 0.914, Testing Acc= 0.868664, Max Final Accuracy=  0.873272, Max AUC=  0.935293, Max AP=  0.920720, Max Q=  -1.899111
# Step 160, Reward=-28.176994, Minibatch Loss= 0.2552, Training Accuracy= 0.914, Testing Acc= 0.861751, Max Final Accuracy=  0.873272, Max AUC=  0.936270, Max AP=  0.919574, Max Q=  -1.878871
# Step 160, Reward=-28.15209, Minibatch Loss= 0.2526, Training Accuracy= 0.914, Testing Acc= 0.866359, Max Final Accuracy=  0.880184, Max AUC=  0.937523, Max AP=  0.919009, Max Q=  -1.858995
# Step 160, Reward=-28.365524, Minibatch Loss= 0.2555, Training Accuracy= 0.914, Testing Acc= 0.870968, Max Final Accuracy=  0.873272, Max AUC=  0.937969, Max AP=  0.920631, Max Q=  -1.890212
# Step 160, Reward=-28.362728, Minibatch Loss= 0.2534, Training Accuracy= 0.914, Testing Acc= 0.873272, Max Final Accuracy=  0.884793, Max AUC=  0.934019, Max AP=  0.913224, Max Q=  -1.877689
# Step 160, Reward=-28.248152, Minibatch Loss= 0.2554, Training Accuracy= 0.914, Testing Acc= 0.877880, Max Final Accuracy=  0.877880, Max AUC=  0.934783, Max AP=  0.917424, Max Q=  -1.914441
# Step 170, Reward=-27.509352, Minibatch Loss= 0.2831, Training Accuracy= 0.906, Testing Acc= 0.866359, Max Final Accuracy=  0.873272, Max AUC=  0.935293, Max AP=  0.920720, Max Q=  -1.870630
# Step 170, Reward=-28.22303, Minibatch Loss= 0.2845, Training Accuracy= 0.898, Testing Acc= 0.859447, Max Final Accuracy=  0.873272, Max AUC=  0.936270, Max AP=  0.919574, Max Q=  -1.865198
# Step 170, Reward=-27.146027, Minibatch Loss= 0.2932, Training Accuracy= 0.906, Testing Acc= 0.868664, Max Final Accuracy=  0.880184, Max AUC=  0.937523, Max AP=  0.919009, Max Q=  -1.860424
# Step 170, Reward=-27.705284, Minibatch Loss= 0.2883, Training Accuracy= 0.898, Testing Acc= 0.857143, Max Final Accuracy=  0.873272, Max AUC=  0.937969, Max AP=  0.920631, Max Q=  -1.853729
# Step 170, Reward=-27.592691, Minibatch Loss= 0.2839, Training Accuracy= 0.898, Testing Acc= 0.866359, Max Final Accuracy=  0.884793, Max AUC=  0.934019, Max AP=  0.913224, Max Q=  -1.856144
# Step 170, Reward=-28.190302, Minibatch Loss= 0.2888, Training Accuracy= 0.906, Testing Acc= 0.870968, Max Final Accuracy=  0.877880, Max AUC=  0.934783, Max AP=  0.917424, Max Q=  -1.871514
# Step 180, Reward=-26.298702, Minibatch Loss= 0.3174, Training Accuracy= 0.859, Testing Acc= 0.868664, Max Final Accuracy=  0.873272, Max AUC=  0.935293, Max AP=  0.920720, Max Q=  -1.941460
# Step 180, Reward=-26.710182, Minibatch Loss= 0.3111, Training Accuracy= 0.867, Testing Acc= 0.864055, Max Final Accuracy=  0.873272, Max AUC=  0.936270, Max AP=  0.919574, Max Q=  -1.960876
# Step 180, Reward=-26.688019, Minibatch Loss= 0.3128, Training Accuracy= 0.859, Testing Acc= 0.866359, Max Final Accuracy=  0.880184, Max AUC=  0.937523, Max AP=  0.919009, Max Q=  -1.947271
# Step 180, Reward=-26.739775, Minibatch Loss= 0.3112, Training Accuracy= 0.859, Testing Acc= 0.864055, Max Final Accuracy=  0.873272, Max AUC=  0.937969, Max AP=  0.920631, Max Q=  -1.995327
# Step 180, Reward=-26.814657, Minibatch Loss= 0.3193, Training Accuracy= 0.867, Testing Acc= 0.861751, Max Final Accuracy=  0.884793, Max AUC=  0.934019, Max AP=  0.913224, Max Q=  -1.976987
# Step 180, Reward=-26.787628, Minibatch Loss= 0.3091, Training Accuracy= 0.859, Testing Acc= 0.866359, Max Final Accuracy=  0.877880, Max AUC=  0.934783, Max AP=  0.917424, Max Q=  -1.968389
# Step 190, Reward=-25.935394, Minibatch Loss= 0.2345, Training Accuracy= 0.906, Testing Acc= 0.870968, Max Final Accuracy=  0.873272, Max AUC=  0.935293, Max AP=  0.920720, Max Q=  -1.930663
# Step 190, Reward=-25.666557, Minibatch Loss= 0.2488, Training Accuracy= 0.898, Testing Acc= 0.870968, Max Final Accuracy=  0.880184, Max AUC=  0.937523, Max AP=  0.919009, Max Q=  -1.946985
# Step 190, Reward=-25.462366, Minibatch Loss= 0.2460, Training Accuracy= 0.914, Testing Acc= 0.877880, Max Final Accuracy=  0.877880, Max AUC=  0.930684, Max AP=  0.908297, Max Q=  -1.928500
# Step 190, Reward=-25.864399, Minibatch Loss= 0.2416, Training Accuracy= 0.891, Testing Acc= 0.870968, Max Final Accuracy=  0.873272, Max AUC=  0.937969, Max AP=  0.920631, Max Q=  -1.947677
# Step 190, Reward=-25.509174, Minibatch Loss= 0.2459, Training Accuracy= 0.906, Testing Acc= 0.875576, Max Final Accuracy=  0.884793, Max AUC=  0.934019, Max AP=  0.913224, Max Q=  -1.935364
# Step 190, Reward=-25.558361, Minibatch Loss= 0.2463, Training Accuracy= 0.922, Testing Acc= 0.870968, Max Final Accuracy=  0.877880, Max AUC=  0.934783, Max AP=  0.917424, Max Q=  -1.922971
# Step 200, Reward=-24.028847, Minibatch Loss= 0.2439, Training Accuracy= 0.891, Testing Acc= 0.873272, Max Final Accuracy=  0.873272, Max AUC=  0.935293, Max AP=  0.920720, Max Q=  -1.928159
# Step 200, Reward=-24.37751, Minibatch Loss= 0.2418, Training Accuracy= 0.891, Testing Acc= 0.875576, Max Final Accuracy=  0.880184, Max AUC=  0.937523, Max AP=  0.919009, Max Q=  -1.924930
# Step 200, Reward=-24.149063, Minibatch Loss= 0.2393, Training Accuracy= 0.891, Testing Acc= 0.868664, Max Final Accuracy=  0.877880, Max AUC=  0.930684, Max AP=  0.908297, Max Q=  -1.933366
# Step 200, Reward=-24.217575, Minibatch Loss= 0.2425, Training Accuracy= 0.891, Testing Acc= 0.868664, Max Final Accuracy=  0.873272, Max AUC=  0.937969, Max AP=  0.920631, Max Q=  -1.959605
# Step 200, Reward=-24.593712, Minibatch Loss= 0.2370, Training Accuracy= 0.898, Testing Acc= 0.864055, Max Final Accuracy=  0.884793, Max AUC=  0.934019, Max AP=  0.913224, Max Q=  -1.955204
# Step 200, Reward=-24.431477, Minibatch Loss= 0.2456, Training Accuracy= 0.898, Testing Acc= 0.864055, Max Final Accuracy=  0.877880, Max AUC=  0.934783, Max AP=  0.917424, Max Q=  -1.917021
# Step 210, Reward=-23.765862, Minibatch Loss= 0.2560, Training Accuracy= 0.914, Testing Acc= 0.868664, Max Final Accuracy=  0.873272, Max AUC=  0.935293, Max AP=  0.920720, Max Q=  -1.839256
# Step 210, Reward=-23.32584, Minibatch Loss= 0.2520, Training Accuracy= 0.914, Testing Acc= 0.877880, Max Final Accuracy=  0.880184, Max AUC=  0.937523, Max AP=  0.919009, Max Q=  -1.880477
# Step 210, Reward=-23.982477, Minibatch Loss= 0.2513, Training Accuracy= 0.930, Testing Acc= 0.866359, Max Final Accuracy=  0.877880, Max AUC=  0.930684, Max AP=  0.908297, Max Q=  -1.873651
# Step 210, Reward=-23.995003, Minibatch Loss= 0.2515, Training Accuracy= 0.914, Testing Acc= 0.861751, Max Final Accuracy=  0.873272, Max AUC=  0.937969, Max AP=  0.920631, Max Q=  -1.893888
# Step 210, Reward=-24.449411, Minibatch Loss= 0.2485, Training Accuracy= 0.922, Testing Acc= 0.861751, Max Final Accuracy=  0.884793, Max AUC=  0.934019, Max AP=  0.913224, Max Q=  -1.895881
# Step 210, Reward=-24.667519, Minibatch Loss= 0.2429, Training Accuracy= 0.914, Testing Acc= 0.866359, Max Final Accuracy=  0.877880, Max AUC=  0.934783, Max AP=  0.917424, Max Q=  -1.860966
# Step 220, Reward=-27.064087, Minibatch Loss= 0.3105, Training Accuracy= 0.852, Testing Acc= 0.861751, Max Final Accuracy=  0.873272, Max AUC=  0.935293, Max AP=  0.920720, Max Q=  -1.888922
# Step 220, Reward=-26.825167, Minibatch Loss= 0.3072, Training Accuracy= 0.852, Testing Acc= 0.859447, Max Final Accuracy=  0.880184, Max AUC=  0.937523, Max AP=  0.919009, Max Q=  -1.892312
# Step 220, Reward=-26.95959, Minibatch Loss= 0.3106, Training Accuracy= 0.852, Testing Acc= 0.857143, Max Final Accuracy=  0.877880, Max AUC=  0.930684, Max AP=  0.908297, Max Q=  -1.879051
# Step 220, Reward=-26.982391, Minibatch Loss= 0.3037, Training Accuracy= 0.867, Testing Acc= 0.861751, Max Final Accuracy=  0.873272, Max AUC=  0.937969, Max AP=  0.920631, Max Q=  -1.890101
# Step 220, Reward=-26.519493, Minibatch Loss= 0.3171, Training Accuracy= 0.852, Testing Acc= 0.866359, Max Final Accuracy=  0.884793, Max AUC=  0.934019, Max AP=  0.913224, Max Q=  -1.917763
# Step 220, Reward=-26.733004, Minibatch Loss= 0.3213, Training Accuracy= 0.867, Testing Acc= 0.868664, Max Final Accuracy=  0.877880, Max AUC=  0.934783, Max AP=  0.917424, Max Q=  -1.953718
# Step 230, Reward=-24.35968, Minibatch Loss= 0.3533, Training Accuracy= 0.852, Testing Acc= 0.861751, Max Final Accuracy=  0.873272, Max AUC=  0.935293, Max AP=  0.920720, Max Q=  -1.900097
# Step 230, Reward=-24.032082, Minibatch Loss= 0.3506, Training Accuracy= 0.844, Testing Acc= 0.868664, Max Final Accuracy=  0.880184, Max AUC=  0.937523, Max AP=  0.919009, Max Q=  -1.892861
# Step 230, Reward=-24.242794, Minibatch Loss= 0.3553, Training Accuracy= 0.836, Testing Acc= 0.873272, Max Final Accuracy=  0.877880, Max AUC=  0.930684, Max AP=  0.908297, Max Q=  -1.895866
# Step 230, Reward=-24.393562, Minibatch Loss= 0.3703, Training Accuracy= 0.836, Testing Acc= 0.868664, Max Final Accuracy=  0.873272, Max AUC=  0.937969, Max AP=  0.920631, Max Q=  -1.907250
# Step 230, Reward=-24.604671, Minibatch Loss= 0.3554, Training Accuracy= 0.844, Testing Acc= 0.870968, Max Final Accuracy=  0.884793, Max AUC=  0.934019, Max AP=  0.913224, Max Q=  -1.898553
# Step 230, Reward=-24.772985, Minibatch Loss= 0.3473, Training Accuracy= 0.836, Testing Acc= 0.866359, Max Final Accuracy=  0.877880, Max AUC=  0.934783, Max AP=  0.917424, Max Q=  -1.905408
# Step 240, Reward=-25.34147, Minibatch Loss= 0.3812, Training Accuracy= 0.852, Testing Acc= 0.866359, Max Final Accuracy=  0.873272, Max AUC=  0.935293, Max AP=  0.920720, Max Q=  -2.075329
# Step 240, Reward=-25.496096, Minibatch Loss= 0.3746, Training Accuracy= 0.852, Testing Acc= 0.868664, Max Final Accuracy=  0.880184, Max AUC=  0.937523, Max AP=  0.919009, Max Q=  -2.074891
# Step 240, Reward=-25.639174, Minibatch Loss= 0.3831, Training Accuracy= 0.844, Testing Acc= 0.866359, Max Final Accuracy=  0.877880, Max AUC=  0.930684, Max AP=  0.908297, Max Q=  -2.080293
# Step 240, Reward=-25.932617, Minibatch Loss= 0.3883, Training Accuracy= 0.844, Testing Acc= 0.870968, Max Final Accuracy=  0.873272, Max AUC=  0.937969, Max AP=  0.920631, Max Q=  -2.091260
# Step 240, Reward=-25.559233, Minibatch Loss= 0.3802, Training Accuracy= 0.852, Testing Acc= 0.870968, Max Final Accuracy=  0.884793, Max AUC=  0.934019, Max AP=  0.913224, Max Q=  -2.087897
# Step 240, Reward=-25.377956, Minibatch Loss= 0.3736, Training Accuracy= 0.852, Testing Acc= 0.873272, Max Final Accuracy=  0.877880, Max AUC=  0.934783, Max AP=  0.917424, Max Q=  -2.069438
# Step 250, Reward=-27.460327, Minibatch Loss= 0.2825, Training Accuracy= 0.891, Testing Acc= 0.866359, Max Final Accuracy=  0.873272, Max AUC=  0.935293, Max AP=  0.920720, Max Q=  -2.071470
# Step 250, Reward=-27.534826, Minibatch Loss= 0.2752, Training Accuracy= 0.898, Testing Acc= 0.864055, Max Final Accuracy=  0.880184, Max AUC=  0.937523, Max AP=  0.919009, Max Q=  -2.065843
# Step 250, Reward=-27.490767, Minibatch Loss= 0.2788, Training Accuracy= 0.898, Testing Acc= 0.864055, Max Final Accuracy=  0.877880, Max AUC=  0.930684, Max AP=  0.908297, Max Q=  -2.076372
# Step 250, Reward=-27.802284, Minibatch Loss= 0.2737, Training Accuracy= 0.898, Testing Acc= 0.864055, Max Final Accuracy=  0.873272, Max AUC=  0.937969, Max AP=  0.920631, Max Q=  -2.088693
# ...
# Step 1560, Reward=-22.40143, Minibatch Loss= 0.3236, Training Accuracy= 0.859, Testing Acc= 0.882488, Max Final Accuracy=  0.896313, Max AUC=  0.944764, Max AP=  0.933588, Max Q=  -2.611570
# Step 2280, Reward=-23.936665, Minibatch Loss= 0.2328, Training Accuracy= 0.906, Testing Acc= 0.894009, Max Final Accuracy=  0.907834, Max AUC=  0.940772, Max AP=  0.918429, Max Q=  -2.662542
# Step 3550, Reward=-21.224089, Minibatch Loss= 0.3129, Training Accuracy= 0.891, Testing Acc= 0.877880, Max Final Accuracy=  0.898618, Max AUC=  0.943341, Max AP=  0.927956, Max Q=  -2.836804
# Step 1620, Reward=-25.056313, Minibatch Loss= 0.3142, Training Accuracy= 0.844, Testing Acc= 0.882488, Max Final Accuracy=  0.896313, Max AUC=  0.938436, Max AP=  0.922590, Max Q=  -2.756819
# Step 3390, Reward=-23.124502, Minibatch Loss= 0.2660, Training Accuracy= 0.867, Testing Acc= 0.891705, Max Final Accuracy=  0.900922, Max AUC=  0.939837, Max AP=  0.920780, Max Q=  -2.664976
# Step 1370, Reward=-20.436844, Minibatch Loss= 0.2629, Training Accuracy= 0.867, Testing Acc= 0.887097, Max Final Accuracy=  0.898618, Max AUC=  0.944870, Max AP=  0.928351, Max Q=  -2.523487
# Step 1570, Reward=-21.796534, Minibatch Loss= 0.3779, Training Accuracy= 0.820, Testing Acc= 0.882488, Max Final Accuracy=  0.896313, Max AUC=  0.944764, Max AP=  0.933588, Max Q=  -2.597575
# Step 2290, Reward=-24.59868, Minibatch Loss= 0.2773, Training Accuracy= 0.867, Testing Acc= 0.882488, Max Final Accuracy=  0.907834, Max AUC=  0.940772, Max AP=  0.918429, Max Q=  -2.578179
# Step 3560, Reward=-23.182373, Minibatch Loss= 0.2598, Training Accuracy= 0.906, Testing Acc= 0.889401, Max Final Accuracy=  0.898618, Max AUC=  0.943341, Max AP=  0.927956, Max Q=  -2.845647
# Step 1630, Reward=-23.92744, Minibatch Loss= 0.2681, Training Accuracy= 0.906, Testing Acc= 0.884793, Max Final Accuracy=  0.896313, Max AUC=  0.938436, Max AP=  0.922590, Max Q=  -2.768822
# Step 3400, Reward=-22.506538, Minibatch Loss= 0.2328, Training Accuracy= 0.922, Testing Acc= 0.896313, Max Final Accuracy=  0.900922, Max AUC=  0.939837, Max AP=  0.920780, Max Q=  -2.721872
# Step 1380, Reward=-22.877125, Minibatch Loss= 0.2857, Training Accuracy= 0.891, Testing Acc= 0.882488, Max Final Accuracy=  0.898618, Max AUC=  0.944870, Max AP=  0.928351, Max Q=  -2.561849
# Step 1580, Reward=-26.541592, Minibatch Loss= 0.2225, Training Accuracy= 0.922, Testing Acc= 0.882488, Max Final Accuracy=  0.896313, Max AUC=  0.944764, Max AP=  0.933588, Max Q=  -2.624166
# Step 2300, Reward=-25.63206, Minibatch Loss= 0.3516, Training Accuracy= 0.867, Testing Acc= 0.880184, Max Final Accuracy=  0.907834, Max AUC=  0.940772, Max AP=  0.918429, Max Q=  -2.654222
# Step 1640, Reward=-22.768906, Minibatch Loss= 0.2085, Training Accuracy= 0.922, Testing Acc= 0.880184, Max Final Accuracy=  0.896313, Max AUC=  0.938436, Max AP=  0.922590, Max Q=  -2.754333
# Step 3570, Reward=-23.810417, Minibatch Loss= 0.2340, Training Accuracy= 0.922, Testing Acc= 0.884793, Max Final Accuracy=  0.898618, Max AUC=  0.943341, Max AP=  0.927956, Max Q=  -2.873976
# Step 3410, Reward=-20.452528, Minibatch Loss= 0.2569, Training Accuracy= 0.891, Testing Acc= 0.877880, Max Final Accuracy=  0.900922, Max AUC=  0.939837, Max AP=  0.920780, Max Q=  -2.647359
# Step 1390, Reward=-20.859371, Minibatch Loss= 0.2594, Training Accuracy= 0.906, Testing Acc= 0.882488, Max Final Accuracy=  0.898618, Max AUC=  0.944870, Max AP=  0.928351, Max Q=  -2.581001
# Step 1590, Reward=-23.164871, Minibatch Loss= 0.2078, Training Accuracy= 0.906, Testing Acc= 0.884793, Max Final Accuracy=  0.896313, Max AUC=  0.944764, Max AP=  0.933588, Max Q=  -2.627096
# Step 2310, Reward=-23.537561, Minibatch Loss= 0.2859, Training Accuracy= 0.883, Testing Acc= 0.875576, Max Final Accuracy=  0.907834, Max AUC=  0.940772, Max AP=  0.918429, Max Q=  -2.597122
# Step 1650, Reward=-24.014091, Minibatch Loss= 0.2425, Training Accuracy= 0.898, Testing Acc= 0.884793, Max Final Accuracy=  0.896313, Max AUC=  0.938436, Max AP=  0.922590, Max Q=  -2.757801
# Step 3580, Reward=-23.304508, Minibatch Loss= 0.1830, Training Accuracy= 0.945, Testing Acc= 0.894009, Max Final Accuracy=  0.898618, Max AUC=  0.943341, Max AP=  0.927956, Max Q=  -2.879505
# Step 3420, Reward=-23.834312, Minibatch Loss= 0.2595, Training Accuracy= 0.906, Testing Acc= 0.882488, Max Final Accuracy=  0.900922, Max AUC=  0.939837, Max AP=  0.920780, Max Q=  -2.674409
# Step 1400, Reward=-22.376606, Minibatch Loss= 0.1551, Training Accuracy= 0.945, Testing Acc= 0.875576, Max Final Accuracy=  0.898618, Max AUC=  0.944870, Max AP=  0.928351, Max Q=  -2.581636
# Step 1600, Reward=-22.241695, Minibatch Loss= 0.3219, Training Accuracy= 0.844, Testing Acc= 0.880184, Max Final Accuracy=  0.896313, Max AUC=  0.944764, Max AP=  0.933588, Max Q=  -2.627675
# Step 2320, Reward=-23.610256, Minibatch Loss= 0.2361, Training Accuracy= 0.930, Testing Acc= 0.891705, Max Final Accuracy=  0.907834, Max AUC=  0.940772, Max AP=  0.918429, Max Q=  -2.592129
# Step 1660, Reward=-23.39691, Minibatch Loss= 0.3056, Training Accuracy= 0.875, Testing Acc= 0.889401, Max Final Accuracy=  0.896313, Max AUC=  0.938436, Max AP=  0.922590, Max Q=  -2.772531
# Step 3590, Reward=-21.704844, Minibatch Loss= 0.2382, Training Accuracy= 0.898, Testing Acc= 0.891705, Max Final Accuracy=  0.898618, Max AUC=  0.943341, Max AP=  0.927956, Max Q=  -2.874558
# Step 3430, Reward=-20.54575, Minibatch Loss= 0.2559, Training Accuracy= 0.914, Testing Acc= 0.884793, Max Final Accuracy=  0.900922, Max AUC=  0.939837, Max AP=  0.920780, Max Q=  -2.709650
# Step 1410, Reward=-19.1791, Minibatch Loss= 0.2699, Training Accuracy= 0.891, Testing Acc= 0.877880, Max Final Accuracy=  0.898618, Max AUC=  0.944870, Max AP=  0.928351, Max Q=  -2.565148
# Step 1610, Reward=-24.416487, Minibatch Loss= 0.2394, Training Accuracy= 0.906, Testing Acc= 0.884793, Max Final Accuracy=  0.896313, Max AUC=  0.944764, Max AP=  0.933588, Max Q=  -2.626587
# Step 2330, Reward=-21.4987, Minibatch Loss= 0.2386, Training Accuracy= 0.914, Testing Acc= 0.884793, Max Final Accuracy=  0.907834, Max AUC=  0.940772, Max AP=  0.918429, Max Q=  -2.643508
# Step 1670, Reward=-25.343994, Minibatch Loss= 0.2512, Training Accuracy= 0.898, Testing Acc= 0.887097, Max Final Accuracy=  0.896313, Max AUC=  0.938436, Max AP=  0.922590, Max Q=  -2.759729
# Step 3600, Reward=-23.350908, Minibatch Loss= 0.2562, Training Accuracy= 0.898, Testing Acc= 0.880184, Max Final Accuracy=  0.898618, Max AUC=  0.943341, Max AP=  0.927956, Max Q=  -2.850955
# Step 3440, Reward=-24.117733, Minibatch Loss= 0.2837, Training Accuracy= 0.906, Testing Acc= 0.884793, Max Final Accuracy=  0.900922, Max AUC=  0.939837, Max AP=  0.920780, Max Q=  -2.673177
# Step 1420, Reward=-22.223223, Minibatch Loss= 0.2632, Training Accuracy= 0.867, Testing Acc= 0.882488, Max Final Accuracy=  0.898618, Max AUC=  0.944870, Max AP=  0.928351, Max Q=  -2.554298
# Step 1620, Reward=-22.20772, Minibatch Loss= 0.1907, Training Accuracy= 0.914, Testing Acc= 0.880184, Max Final Accuracy=  0.896313, Max AUC=  0.944764, Max AP=  0.933588, Max Q=  -2.655579
# Step 2340, Reward=-21.663017, Minibatch Loss= 0.2976, Training Accuracy= 0.891, Testing Acc= 0.884793, Max Final Accuracy=  0.907834, Max AUC=  0.940772, Max AP=  0.918429, Max Q=  -2.614367
# Step 1680, Reward=-22.236042, Minibatch Loss= 0.2315, Training Accuracy= 0.906, Testing Acc= 0.884793, Max Final Accuracy=  0.896313, Max AUC=  0.938436, Max AP=  0.922590, Max Q=  -2.753663
# Step 3610, Reward=-23.088692, Minibatch Loss= 0.2229, Training Accuracy= 0.914, Testing Acc= 0.884793, Max Final Accuracy=  0.898618, Max AUC=  0.943341, Max AP=  0.927956, Max Q=  -2.906597
# Step 3450, Reward=-21.96751, Minibatch Loss= 0.2828, Training Accuracy= 0.891, Testing Acc= 0.889401, Max Final Accuracy=  0.900922, Max AUC=  0.939837, Max AP=  0.920780, Max Q=  -2.685209
# Step 1430, Reward=-21.40573, Minibatch Loss= 0.2328, Training Accuracy= 0.914, Testing Acc= 0.891705, Max Final Accuracy=  0.898618, Max AUC=  0.944870, Max AP=  0.928351, Max Q=  -2.537037
# Step 1630, Reward=-21.36633, Minibatch Loss= 0.2614, Training Accuracy= 0.883, Testing Acc= 0.880184, Max Final Accuracy=  0.896313, Max AUC=  0.944764, Max AP=  0.933588, Max Q=  -2.592098
# Step 2350, Reward=-24.5321, Minibatch Loss= 0.2054, Training Accuracy= 0.914, Testing Acc= 0.884793, Max Final Accuracy=  0.907834, Max AUC=  0.940772, Max AP=  0.918429, Max Q=  -2.587678
# Step 1690, Reward=-23.581467, Minibatch Loss= 0.2528, Training Accuracy= 0.922, Testing Acc= 0.877880, Max Final Accuracy=  0.896313, Max AUC=  0.938436, Max AP=  0.922590, Max Q=  -2.754653
# Step 3620, Reward=-24.273056, Minibatch Loss= 0.1877, Training Accuracy= 0.922, Testing Acc= 0.880184, Max Final Accuracy=  0.898618, Max AUC=  0.943341, Max AP=  0.927956, Max Q=  -2.860254
# Step 3460, Reward=-23.213379, Minibatch Loss= 0.3122, Training Accuracy= 0.883, Testing Acc= 0.889401, Max Final Accuracy=  0.900922, Max AUC=  0.939837, Max AP=  0.920780, Max Q=  -2.693600
# Step 1440, Reward=-23.143633, Minibatch Loss= 0.1846, Training Accuracy= 0.945, Testing Acc= 0.894009, Max Final Accuracy=  0.898618, Max AUC=  0.944870, Max AP=  0.928351, Max Q=  -2.538446
# Step 1640, Reward=-24.317976, Minibatch Loss= 0.2693, Training Accuracy= 0.875, Testing Acc= 0.882488, Max Final Accuracy=  0.896313, Max AUC=  0.944764, Max AP=  0.933588, Max Q=  -2.647945
# Step 2360, Reward=-21.99697, Minibatch Loss= 0.2889, Training Accuracy= 0.898, Testing Acc= 0.873272, Max Final Accuracy=  0.907834, Max AUC=  0.940772, Max AP=  0.918429, Max Q=  -2.642196
# Step 1700, Reward=-23.231781, Minibatch Loss= 0.2684, Training Accuracy= 0.906, Testing Acc= 0.884793, Max Final Accuracy=  0.896313, Max AUC=  0.938436, Max AP=  0.922590, Max Q=  -2.778007
# Step 3470, Reward=-23.44497, Minibatch Loss= 0.2937, Training Accuracy= 0.859, Testing Acc= 0.889401, Max Final Accuracy=  0.900922, Max AUC=  0.939837, Max AP=  0.920780, Max Q=  -2.650463
# Step 3630, Reward=-21.362988, Minibatch Loss= 0.2941, Training Accuracy= 0.898, Testing Acc= 0.887097, Max Final Accuracy=  0.898618, Max AUC=  0.943341, Max AP=  0.927956, Max Q=  -2.874047
# Step 1450, Reward=-21.914032, Minibatch Loss= 0.1961, Training Accuracy= 0.938, Testing Acc= 0.868664, Max Final Accuracy=  0.898618, Max AUC=  0.944870, Max AP=  0.928351, Max Q=  -2.616321
# Step 1650, Reward=-23.257551, Minibatch Loss= 0.2507, Training Accuracy= 0.883, Testing Acc= 0.877880, Max Final Accuracy=  0.896313, Max AUC=  0.944764, Max AP=  0.933588, Max Q=  -2.614845
# Step 2370, Reward=-23.643156, Minibatch Loss= 0.3370, Training Accuracy= 0.828, Testing Acc= 0.873272, Max Final Accuracy=  0.907834, Max AUC=  0.940772, Max AP=  0.918429, Max Q=  -2.575389
# Step 1710, Reward=-23.189358, Minibatch Loss= 0.2820, Training Accuracy= 0.891, Testing Acc= 0.882488, Max Final Accuracy=  0.896313, Max AUC=  0.938436, Max AP=  0.922590, Max Q=  -2.755288
# Step 3480, Reward=-21.636763, Minibatch Loss= 0.3195, Training Accuracy= 0.891, Testing Acc= 0.882488, Max Final Accuracy=  0.900922, Max AUC=  0.939837, Max AP=  0.920780, Max Q=  -2.684152
# Step 3640, Reward=-24.929543, Minibatch Loss= 0.1665, Training Accuracy= 0.953, Testing Acc= 0.884793, Max Final Accuracy=  0.898618, Max AUC=  0.943341, Max AP=  0.927956, Max Q=  -2.855622
# Step 1460, Reward=-21.606289, Minibatch Loss= 0.2131, Training Accuracy= 0.922, Testing Acc= 0.894009, Max Final Accuracy=  0.898618, Max AUC=  0.944870, Max AP=  0.928351, Max Q=  -2.576471
# Step 1660, Reward=-25.642399, Minibatch Loss= 0.2827, Training Accuracy= 0.906, Testing Acc= 0.891705, Max Final Accuracy=  0.896313, Max AUC=  0.944764, Max AP=  0.933588, Max Q=  -2.683151
# Step 2380, Reward=-25.933071, Minibatch Loss= 0.3062, Training Accuracy= 0.867, Testing Acc= 0.887097, Max Final Accuracy=  0.907834, Max AUC=  0.940772, Max AP=  0.918429, Max Q=  -2.600908
# Step 1720, Reward=-23.68438, Minibatch Loss= 0.2980, Training Accuracy= 0.883, Testing Acc= 0.875576, Max Final Accuracy=  0.896313, Max AUC=  0.938436, Max AP=  0.922590, Max Q=  -2.753884
# Step 3490, Reward=-20.509758, Minibatch Loss= 0.1986, Training Accuracy= 0.922, Testing Acc= 0.889401, Max Final Accuracy=  0.900922, Max AUC=  0.939837, Max AP=  0.920780, Max Q=  -2.706732
# Step 1470, Reward=-21.499743, Minibatch Loss= 0.2401, Training Accuracy= 0.914, Testing Acc= 0.880184, Max Final Accuracy=  0.898618, Max AUC=  0.944870, Max AP=  0.928351, Max Q=  -2.573704
# Step 3650, Reward=-23.489555, Minibatch Loss= 0.2645, Training Accuracy= 0.875, Testing Acc= 0.882488, Max Final Accuracy=  0.898618, Max AUC=  0.943341, Max AP=  0.927956, Max Q=  -2.870500
# Step 1670, Reward=-24.114532, Minibatch Loss= 0.3454, Training Accuracy= 0.875, Testing Acc= 0.896313, Max Final Accuracy=  0.896313, Max AUC=  0.944764, Max AP=  0.933588, Max Q=  -2.625455
# Step 2390, Reward=-24.886274, Minibatch Loss= 0.2386, Training Accuracy= 0.922, Testing Acc= 0.891705, Max Final Accuracy=  0.907834, Max AUC=  0.940772, Max AP=  0.918429, Max Q=  -2.585670
# Step 1730, Reward=-24.461992, Minibatch Loss= 0.2658, Training Accuracy= 0.898, Testing Acc= 0.884793, Max Final Accuracy=  0.896313, Max AUC=  0.938436, Max AP=  0.922590, Max Q=  -2.734428
# Step 3500, Reward=-23.883867, Minibatch Loss= 0.2827, Training Accuracy= 0.898, Testing Acc= 0.887097, Max Final Accuracy=  0.900922, Max AUC=  0.939837, Max AP=  0.920780, Max Q=  -2.698145
# Step 1480, Reward=-21.230663, Minibatch Loss= 0.1652, Training Accuracy= 0.938, Testing Acc= 0.894009, Max Final Accuracy=  0.898618, Max AUC=  0.944870, Max AP=  0.928351, Max Q=  -2.604625
# Step 3660, Reward=-23.524864, Minibatch Loss= 0.2362, Training Accuracy= 0.891, Testing Acc= 0.889401, Max Final Accuracy=  0.898618, Max AUC=  0.943341, Max AP=  0.927956, Max Q=  -2.857493
# Step 1740, Reward=-22.247656, Minibatch Loss= 0.2228, Training Accuracy= 0.922, Testing Acc= 0.887097, Max Final Accuracy=  0.896313, Max AUC=  0.938436, Max AP=  0.922590, Max Q=  -2.760264
# Step 2400, Reward=-22.018427, Minibatch Loss= 0.2133, Training Accuracy= 0.938, Testing Acc= 0.882488, Max Final Accuracy=  0.907834, Max AUC=  0.940772, Max AP=  0.918429, Max Q=  -2.627019
# Step 1680, Reward=-24.150824, Minibatch Loss= 0.2417, Training Accuracy= 0.914, Testing Acc= 0.884793, Max Final Accuracy=  0.896313, Max AUC=  0.944764, Max AP=  0.933588, Max Q=  -2.674587
# Step 3510, Reward=-23.544485, Minibatch Loss= 0.2394, Training Accuracy= 0.922, Testing Acc= 0.887097, Max Final Accuracy=  0.900922, Max AUC=  0.939837, Max AP=  0.920780, Max Q=  -2.676320
# Step 1490, Reward=-20.656649, Minibatch Loss= 0.2953, Training Accuracy= 0.875, Testing Acc= 0.882488, Max Final Accuracy=  0.898618, Max AUC=  0.944870, Max AP=  0.928351, Max Q=  -2.567808
# Step 1750, Reward=-22.635822, Minibatch Loss= 0.3302, Training Accuracy= 0.852, Testing Acc= 0.880184, Max Final Accuracy=  0.896313, Max AUC=  0.938436, Max AP=  0.922590, Max Q=  -2.780241
# Step 3670, Reward=-24.865934, Minibatch Loss= 0.1578, Training Accuracy= 0.938, Testing Acc= 0.891705, Max Final Accuracy=  0.898618, Max AUC=  0.943341, Max AP=  0.927956, Max Q=  -2.863957
# Step 2410, Reward=-22.047691, Minibatch Loss= 0.2756, Training Accuracy= 0.875, Testing Acc= 0.889401, Max Final Accuracy=  0.907834, Max AUC=  0.940772, Max AP=  0.918429, Max Q=  -2.606136
# Step 1690, Reward=-22.570404, Minibatch Loss= 0.2325, Training Accuracy= 0.898, Testing Acc= 0.894009, Max Final Accuracy=  0.896313, Max AUC=  0.944764, Max AP=  0.933588, Max Q=  -2.649163
# Step 3520, Reward=-21.678024, Minibatch Loss= 0.3301, Training Accuracy= 0.867, Testing Acc= 0.875576, Max Final Accuracy=  0.900922, Max AUC=  0.939837, Max AP=  0.920780, Max Q=  -2.687801
# Step 1500, Reward=-23.473793, Minibatch Loss= 0.2630, Training Accuracy= 0.898, Testing Acc= 0.887097, Max Final Accuracy=  0.898618, Max AUC=  0.944870, Max AP=  0.928351, Max Q=  -2.575256
